# %% [markdown]
# # YOLOv8 Image Detection Pipeline
#
# This notebook runs object detection on Telegram images using YOLOv8 and saves results to PostgreSQL.
#
# ## Setup
# First, let's import the necessary modules and set up the environment.

# %%
import os
import sys
import logging
from datetime import datetime
from typing import List, Dict, Any
from glob import glob

# Add src to path for imports
sys.path.append(os.path.abspath('..'))

# Import our custom modules
from src.enrich.yolo_enricher import YOLOEnricher
from src.loader.postgres_loader import PostgresLoader

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

# Suppress YOLO verbose output
import warnings
warnings.filterwarnings('ignore')

# Disable ultralytics verbose output
import os
os.environ['ULTRALYTICS_VERBOSE'] = 'False'

print("✅ Imports and setup complete")
# Out:
# ✅ Imports and setup complete

# %% [markdown]
# ## Create Silent YOLO Enricher
# Define a YOLO enricher class that suppresses all verbose output.

# %%
class SilentYOLOEnricher:
    def __init__(self):
        self.model_path = os.getenv('YOLO_MODEL_PATH', 'yolov8n.pt')
        self.confidence_threshold = float(os.getenv('CONFIDENCE_THRESHOLD', 0.5))
        self.model = None
        
    def load_model(self):
        """Load YOLO model silently"""
        try:
            from ultralytics import YOLO
            self.model = YOLO(self.model_path, verbose=False)
            print(f"✅ YOLO model loaded successfully")
        except Exception as e:
            print(f"❌ Error loading YOLO model: {e}")
            raise
            
    def detect_objects(self, image_path: str) -> Dict[str, Any]:
        """Detect objects in an image using YOLO silently"""
        if not self.model:
            self.load_model()
            
        try:
            # Run detection with verbose=False
            results = self.model(image_path, conf=self.confidence_threshold, verbose=False)
            
            detections = []
            confidence_scores = {}
            
            for result in results:
                boxes = result.boxes
                if boxes is not None:
                    for box in boxes:
                        # Get box coordinates
                        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                        
                        # Get confidence and class
                        confidence = float(box.conf[0].cpu().numpy())
                        class_id = int(box.cls[0].cpu().numpy())
                        class_name = self.model.names[class_id]
                        
                        detection = {
                            'bbox': [float(x1), float(y1), float(x2), float(y2)],
                            'confidence': confidence,
                            'class_id': class_id,
                            'class_name': class_name
                        }
                        detections.append(detection)
                        
                        # Track confidence scores by class
                        if class_name not in confidence_scores:
                            confidence_scores[class_name] = []
                        confidence_scores[class_name].append(confidence)
            
            # Calculate average confidence for each class
            avg_confidence = {}
            for class_name, scores in confidence_scores.items():
                avg_confidence[class_name] = sum(scores) / len(scores)
            
            return {
                'detections': detections,
                'confidence_scores': avg_confidence,
                'total_detections': len(detections),
                'image_path': image_path
            }
            
        except Exception as e:
            print(f"❌ Error detecting objects in {image_path}: {e}")
            return {
                'detections': [],
                'confidence_scores': {},
                'total_detections': 0,
                'image_path': image_path,
                'error': str(e)
            }

print("✅ Silent YOLO Enricher class defined")
# Out:
# ✅ Silent YOLO Enricher class defined

# %% [markdown]
# ## Configuration
# Set the date and optionally a specific channel to process.

# %%
# Configuration
DATE = "2025-07-14"  # Change this to your target date
CHANNEL = None  # Set to specific channel name (e.g., "tikvahpharma") or None for all channels

# Base directory for images
BASE_DIR = os.path.join('data', 'raw', 'telegram_images', DATE)

print(f"�� Processing date: {DATE}")
print(f"📁 Base directory: {BASE_DIR}")
if CHANNEL:
    print(f"📺 Channel: {CHANNEL}")
else:
    print(f"📺 Channels: All channels in {DATE}")
# Out:
# �� Processing date: 2025-07-14
# 📁 Base directory: data\raw\telegram_images\2025-07-14
# 📺 Channels: All channels in 2025-07-14

# %% [markdown]
# ## Helper Functions
# Define functions to scan images and extract message IDs.

# %%
def get_image_files(base_dir: str, channel: str = None) -> List[str]:
    """Get all jpg image files in the directory."""
    if channel:
        # Specific channel
        channel_dir = os.path.join(base_dir, channel)
        if not os.path.exists(channel_dir):
            logger.error(f"Channel directory not found: {channel_dir}")
            return []
        return glob(os.path.join(channel_dir, '*.jpg'))
    else:
        # All channels
        image_files = []
        if os.path.exists(base_dir):
            for channel_dir in os.listdir(base_dir):
                channel_path = os.path.join(base_dir, channel_dir)
                if os.path.isdir(channel_path):
                    image_files.extend(glob(os.path.join(channel_path, '*.jpg')))
        return image_files

def extract_message_id(image_path: str) -> int:
    """Extract message_id from image filename (e.g., 123456.jpg)."""
    filename = os.path.basename(image_path)
    try:
        return int(os.path.splitext(filename)[0])
    except Exception:
        logger.error(f"Could not extract message_id from {filename}")
        return None

print("✅ Helper functions defined")
# Out:
# ✅ Helper functions defined

# %% [markdown]
# ## Create Database Tables
# Create the necessary tables if they don't exist.

# %%
# Create database tables
loader = PostgresLoader()
loader.connect()

try:
    cursor = loader.conn.cursor()
    
    # Drop existing table if it exists (to fix constraints)
    cursor.execute("DROP TABLE IF EXISTS processed_images CASCADE;")
    loader.conn.commit()
    print("🗑️ Dropped existing table")
    
    # Create processed_images table with proper constraints
    create_table_sql = """
    CREATE TABLE processed_images (
        id SERIAL PRIMARY KEY,
        message_id BIGINT UNIQUE NOT NULL,
        image_path TEXT,
        detection_results JSONB,
        confidence_scores JSONB,
        processed_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    );
    """
    
    cursor.execute(create_table_sql)
    loader.conn.commit()
    print("✅ processed_images table created successfully with UNIQUE constraint")
    
    # Create index for better performance
    cursor.execute("""
        CREATE INDEX IF NOT EXISTS idx_processed_images_message_id 
        ON processed_images(message_id);
    """)
    loader.conn.commit()
    print("✅ Index created successfully")
    
except Exception as e:
    print(f"❌ Error creating tables: {e}")
    loader.conn.rollback()
finally:
    cursor.close()
    loader.disconnect()
    print("🔌 Database connection closed")
# Out:
# Connected to PostgreSQL successfully
# 🗑️ Dropped existing table
# ✅ processed_images table created successfully with UNIQUE constraint
# ✅ Index created successfully
# 🔌 Database connection closed

# %% [markdown]
# ## Check Available Images
# Let's see what images are available for processing.

# %%
# Get image files
image_files = get_image_files(BASE_DIR, CHANNEL)

print(f"📊 Found {len(image_files)} images to process")

if len(image_files) > 0:
    print("\n📋 Sample images:")
    for i, img_path in enumerate(image_files[:5]):
        message_id = extract_message_id(img_path)
        print(f"  {i+1}. {os.path.basename(img_path)} (message_id: {message_id})")
    
    if len(image_files) > 5:
        print(f"  ... and {len(image_files) - 5} more images")
else:
    print("❌ No images found. Check the date and channel configuration.")
# Out:
# 📊 Found 1272 images to process
#
# 📋 Sample images:
#   1. 10.jpg (message_id: 10)
#   2. 11.jpg (message_id: 11)
#   3. 13.jpg (message_id: 13)
#   4. 14.jpg (message_id: 14)
#   5. 15.jpg (message_id: 15)
#   ... and 1267 more images

# %% [markdown]
# ## Initialize YOLO Model and Database Connection
# Load the YOLOv8 model and connect to PostgreSQL.

# %%
# Initialize silent YOLO enricher
print("🤖 Loading YOLOv8 model silently...")
yolo = SilentYOLOEnricher()
yolo.load_model()

# Initialize database loader
print("🗄️ Connecting to PostgreSQL...")
loader = PostgresLoader()
loader.connect()
print("✅ Database connection established")
# Out:
# 🤖 Loading YOLOv8 model silently...
# ✅ YOLO model loaded successfully
# 🗄️ Connecting to PostgreSQL...
# Connected to PostgreSQL successfully
# ✅ Database connection established

# %% [markdown]
# ## Process Images with YOLO Detection
# Run object detection on each image and collect results.

# %%
# Process images with silent YOLO
processed_data = []
errors = []

print(f"🚀 Starting silent object detection on {len(image_files)} images...")

for i, image_path in enumerate(image_files):
    message_id = extract_message_id(image_path)
    if message_id is None:
        errors.append(f"Could not extract message_id from {image_path}")
        continue
    
    try:
        # Run silent YOLO detection
        detection_result = yolo.detect_objects(image_path)
        detections = detection_result.get('detections', [])
        
        # Log progress (only this will show)
        print(f"📸 [{i+1}/{len(image_files)}] {os.path.basename(image_path)}: {len(detections)} objects detected")
        
        # Store results
        processed_data.append({
            'message_id': message_id,
            'image_path': image_path,
            'detection_results': detection_result.get('detections', []),
            'confidence_scores': detection_result.get('confidence_scores', {})
        })
        
    except Exception as e:
        error_msg = f"Error processing {image_path}: {e}"
        print(f"❌ {error_msg}")
        errors.append(error_msg)

print(f"\n✅ Processing complete!")
print(f"📊 Successfully processed: {len(processed_data)} images")
print(f"❌ Errors: {len(errors)} images")
# Out:
# 🚀 Starting silent object detection on 1272 images...
# 📸 [1/1272] 10.jpg: 0 objects detected
# 📸 [2/1272] 11.jpg: 0 objects detected
# 📸 [3/1272] 13.jpg: 1 objects detected
# 📸 [4/1272] 14.jpg: 0 objects detected
# 📸 [5/1272] 15.jpg: 0 objects detected
# 📸 [6/1272] 17.jpg: 1 objects detected
# 📸 [7/1272] 18.jpg: 0 objects detected
# 📸 [8/1272] 19.jpg: 2 objects detected
# 📸 [9/1272] 2.jpg: 0 objects detected
# 📸 [10/1272] 20.jpg: 2 objects detected
# 📸 [11/1272] 21.jpg: 0 objects detected
# 📸 [12/1272] 22.jpg: 0 objects detected
# 📸 [13/1272] 23.jpg: 1 objects detected
# 📸 [14/1272] 25.jpg: 2 objects detected
# 📸 [15/1272] 26.jpg: 1 objects detected
# 📸 [16/1272] 27.jpg: 0 objects detected
# 📸 [17/1272] 30.jpg: 0 objects detected
# 📸 [18/1272] 31.jpg: 1 objects detected
# 📸 [19/1272] 33.jpg: 2 objects detected
# 📸 [20/1272] 34.jpg: 0 objects detected
# 📸 [21/1272] 38.jpg: 0 objects detected
# 📸 [22/1272] 39.jpg: 7 objects detected
# 📸 [23/1272] 40.jpg: 6 objects detected
# 📸 [24/1272] 41.jpg: 0 objects detected
# 📸 [25/1272] 43.jpg: 1 objects detected
# 📸 [26/1272] 45.jpg: 1 objects detected
# 📸 [27/1272] 46.jpg: 1 objects detected
# 📸 [28/1272] 48.jpg: 0 objects detected
# 📸 [29/1272] 49.jpg: 1 objects detected
# 📸 [30/1272] 50.jpg: 0 objects detected
# 📸 [31/1272] 52.jpg: 4 objects detected
# 📸 [32/1272] 55.jpg: 0 objects detected
# 📸 [33/1272] 58.jpg: 0 objects detected
# 📸 [34/1272] 59.jpg: 0 objects detected
# 📸 [35/1272] 60.jpg: 0 objects detected
# 📸 [36/1272] 64.jpg: 1 objects detected
# 📸 [37/1272] 67.jpg: 1 objects detected
# 📸 [38/1272] 70.jpg: 2 objects detected
# 📸 [39/1272] 71.jpg: 2 objects detected
# 📸 [40/1272] 75.jpg: 1 objects detected
# 📸 [41/1272] 76.jpg: 1 objects detected
# 📸 [42/1272] 77.jpg: 4 objects detected
# 📸 [43/1272] 79.jpg: 0 objects detected
# 📸 [44/1272] 80.jpg: 3 objects detected
# 📸 [45/1272] 81.jpg: 5 objects detected
# 📸 [46/1272] 82.jpg: 3 objects detected
# 📸 [47/1272] 85.jpg: 0 objects detected
# 📸 [48/1272] 86.jpg: 1 objects detected
# 📸 [49/1272] 87.jpg: 0 objects detected
# 📸 [50/1272] 88.jpg: 0 objects detected
# 📸 [51/1272] 9.jpg: 0 objects detected
# 📸 [52/1272] 90.jpg: 0 objects detected
# 📸 [53/1272] 91.jpg: 0 objects detected
# 📸 [54/1272] 92.jpg: 0 objects detected
# 📸 [55/1272] 93.jpg: 1 objects detected
# 📸 [56/1272] 94.jpg: 1 objects detected
# 📸 [57/1272] 95.jpg: 1 objects detected
# 📸 [58/1272] 96.jpg: 0 objects detected
# 📸 [59/1272] 97.jpg: 0 objects detected
# 📸 [60/1272] 17540.jpg: 0 objects detected
# 📸 [61/1272] 17541.jpg: 1 objects detected
# 📸 [62/1272] 17542.jpg: 1 objects detected
# 📸 [63/1272] 17543.jpg: 1 objects detected
# 📸 [64/1272] 17544.jpg: 0 objects detected
# 📸 [65/1272] 17545.jpg: 1 objects detected
# 📸 [66/1272] 17546.jpg: 0 objects detected
# 📸 [67/1272] 17547.jpg: 0 objects detected
# 📸 [68/1272] 17548.jpg: 1 objects detected
# 📸 [69/1272] 17549.jpg: 0 objects detected
# 📸 [70/1272] 17550.jpg: 1 objects detected
# 📸 [71/1272] 17551.jpg: 0 objects detected
# 📸 [72/1272] 17552.jpg: 0 objects detected
# 📸 [73/1272] 17553.jpg: 0 objects detected
# 📸 [74/1272] 17554.jpg: 1 objects detected
# 📸 [75/1272] 17555.jpg: 0 objects detected
# 📸 [76/1272] 17556.jpg: 0 objects detected
# 📸 [77/1272] 17557.jpg: 0 objects detected
# 📸 [78/1272] 17558.jpg: 0 objects detected
# 📸 [79/1272] 17559.jpg: 0 objects detected
# 📸 [80/1272] 17560.jpg: 0 objects detected
# 📸 [81/1272] 17561.jpg: 1 objects detected
# 📸 [82/1272] 17562.jpg: 1 objects detected
# 📸 [83/1272] 17563.jpg: 0 objects detected
# 📸 [84/1272] 17564.jpg: 0 objects detected
# 📸 [85/1272] 17565.jpg: 0 objects detected
# 📸 [86/1272] 17566.jpg: 1 objects detected
# 📸 [87/1272] 17567.jpg: 0 objects detected
# 📸 [88/1272] 17568.jpg: 1 objects detected
# 📸 [89/1272] 17569.jpg: 1 objects detected
# 📸 [90/1272] 17570.jpg: 1 objects detected
# 📸 [91/1272] 17571.jpg: 1 objects detected
# 📸 [92/1272] 17572.jpg: 0 objects detected
# 📸 [93/1272] 17573.jpg: 0 objects detected
# 📸 [94/1272] 17574.jpg: 0 objects detected
# 📸 [95/1272] 17575.jpg: 1 objects detected
# 📸 [96/1272] 17576.jpg: 1 objects detected
# 📸 [97/1272] 17577.jpg: 0 objects detected
# 📸 [98/1272] 17578.jpg: 0 objects detected
# 📸 [99/1272] 17579.jpg: 0 objects detected
# 📸 [100/1272] 17580.jpg: 0 objects detected
# 📸 [101/1272] 17581.jpg: 0 objects detected
# 📸 [102/1272] 17582.jpg: 1 objects detected
# 📸 [103/1272] 17583.jpg: 0 objects detected
# 📸 [104/1272] 17584.jpg: 1 objects detected
# 📸 [105/1272] 17585.jpg: 1 objects detected
# 📸 [106/1272] 17586.jpg: 0 objects detected
# 📸 [107/1272] 17587.jpg: 0 objects detected
# 📸 [108/1272] 17588.jpg: 0 objects detected
# 📸 [109/1272] 17589.jpg: 0 objects detected
# 📸 [110/1272] 17590.jpg: 0 objects detected
# 📸 [111/1272] 17591.jpg: 0 objects detected
# 📸 [112/1272] 17592.jpg: 0 objects detected
# 📸 [113/1272] 17593.jpg: 0 objects detected
# 📸 [114/1272] 17594.jpg: 1 objects detected
# 📸 [115/1272] 17595.jpg: 0 objects detected
# 📸 [116/1272] 17596.jpg: 0 objects detected
# 📸 [117/1272] 17597.jpg: 1 objects detected
# 📸 [118/1272] 17598.jpg: 0 objects detected
# 📸 [119/1272] 17599.jpg: 1 objects detected
# 📸 [120/1272] 17600.jpg: 1 objects detected
# 📸 [121/1272] 17601.jpg: 0 objects detected
# 📸 [122/1272] 17602.jpg: 0 objects detected
# 📸 [123/1272] 17603.jpg: 0 objects detected
# 📸 [124/1272] 17604.jpg: 1 objects detected
# 📸 [125/1272] 17605.jpg: 0 objects detected
# 📸 [126/1272] 17606.jpg: 0 objects detected
# 📸 [127/1272] 17607.jpg: 0 objects detected
# 📸 [128/1272] 17608.jpg: 0 objects detected
# 📸 [129/1272] 17609.jpg: 0 objects detected
# 📸 [130/1272] 17610.jpg: 1 objects detected
# 📸 [131/1272] 17611.jpg: 0 objects detected
# 📸 [132/1272] 17612.jpg: 0 objects detected
# 📸 [133/1272] 17613.jpg: 0 objects detected
# 📸 [134/1272] 17614.jpg: 0 objects detected
# 📸 [135/1272] 17615.jpg: 1 objects detected
# 📸 [136/1272] 17618.jpg: 1 objects detected
# 📸 [137/1272] 17621.jpg: 0 objects detected
# 📸 [138/1272] 17622.jpg: 0 objects detected
# 📸 [139/1272] 17623.jpg: 0 objects detected
# 📸 [140/1272] 17624.jpg: 0 objects detected
# 📸 [141/1272] 17625.jpg: 0 objects detected
# 📸 [142/1272] 17626.jpg: 0 objects detected
# 📸 [143/1272] 17627.jpg: 0 objects detected
# 📸 [144/1272] 17628.jpg: 0 objects detected
# 📸 [145/1272] 17629.jpg: 1 objects detected
# 📸 [146/1272] 17630.jpg: 1 objects detected
# 📸 [147/1272] 17631.jpg: 0 objects detected
# 📸 [148/1272] 17632.jpg: 0 objects detected
# 📸 [149/1272] 17633.jpg: 1 objects detected
# 📸 [150/1272] 17634.jpg: 1 objects detected
# 📸 [151/1272] 17635.jpg: 0 objects detected
# 📸 [152/1272] 17636.jpg: 1 objects detected
# 📸 [153/1272] 17637.jpg: 0 objects detected
# 📸 [154/1272] 17638.jpg: 1 objects detected
# 📸 [155/1272] 17639.jpg: 0 objects detected
# 📸 [156/1272] 17640.jpg: 1 objects detected
# 📸 [157/1272] 17641.jpg: 1 objects detected
# 📸 [158/1272] 17642.jpg: 0 objects detected
# 📸 [159/1272] 17643.jpg: 0 objects detected
# 📸 [160/1272] 17644.jpg: 0 objects detected
# 📸 [161/1272] 17645.jpg: 0 objects detected
# 📸 [162/1272] 17646.jpg: 0 objects detected
# 📸 [163/1272] 17647.jpg: 0 objects detected
# 📸 [164/1272] 17648.jpg: 0 objects detected
# 📸 [165/1272] 17649.jpg: 0 objects detected
# 📸 [166/1272] 17650.jpg: 1 objects detected
# 📸 [167/1272] 17651.jpg: 0 objects detected
# 📸 [168/1272] 17652.jpg: 1 objects detected
# 📸 [169/1272] 17653.jpg: 1 objects detected
# 📸 [170/1272] 17654.jpg: 1 objects detected
# 📸 [171/1272] 17655.jpg: 0 objects detected
# 📸 [172/1272] 17656.jpg: 0 objects detected
# 📸 [173/1272] 17657.jpg: 1 objects detected
# 📸 [174/1272] 17658.jpg: 0 objects detected
# 📸 [175/1272] 17659.jpg: 0 objects detected
# 📸 [176/1272] 17660.jpg: 0 objects detected
# 📸 [177/1272] 17661.jpg: 0 objects detected
# 📸 [178/1272] 17662.jpg: 1 objects detected
# 📸 [179/1272] 17663.jpg: 0 objects detected
# 📸 [180/1272] 17664.jpg: 0 objects detected
# 📸 [181/1272] 17665.jpg: 0 objects detected
# 📸 [182/1272] 17666.jpg: 1 objects detected
# 📸 [183/1272] 17667.jpg: 1 objects detected
# 📸 [184/1272] 17668.jpg: 0 objects detected
# 📸 [185/1272] 17669.jpg: 1 objects detected
# 📸 [186/1272] 17670.jpg: 1 objects detected
# 📸 [187/1272] 17671.jpg: 0 objects detected
# 📸 [188/1272] 17672.jpg: 0 objects detected
# 📸 [189/1272] 17673.jpg: 1 objects detected
# 📸 [190/1272] 17674.jpg: 1 objects detected
# 📸 [191/1272] 17675.jpg: 0 objects detected
# 📸 [192/1272] 17676.jpg: 0 objects detected
# 📸 [193/1272] 17677.jpg: 0 objects detected
# 📸 [194/1272] 17678.jpg: 0 objects detected
# 📸 [195/1272] 17679.jpg: 1 objects detected
# 📸 [196/1272] 17680.jpg: 0 objects detected
# 📸 [197/1272] 17681.jpg: 0 objects detected
# 📸 [198/1272] 17682.jpg: 0 objects detected
# 📸 [199/1272] 17683.jpg: 1 objects detected
# 📸 [200/1272] 17685.jpg: 0 objects detected
# 📸 [201/1272] 17686.jpg: 0 objects detected
# 📸 [202/1272] 17687.jpg: 1 objects detected
# 📸 [203/1272] 17688.jpg: 0 objects detected
# 📸 [204/1272] 17689.jpg: 1 objects detected
# 📸 [205/1272] 17690.jpg: 0 objects detected
# 📸 [206/1272] 17691.jpg: 1 objects detected
# 📸 [207/1272] 17692.jpg: 0 objects detected
# 📸 [208/1272] 17693.jpg: 0 objects detected
# 📸 [209/1272] 17694.jpg: 1 objects detected
# 📸 [210/1272] 17695.jpg: 0 objects detected
# 📸 [211/1272] 17696.jpg: 0 objects detected
# 📸 [212/1272] 17697.jpg: 0 objects detected
# 📸 [213/1272] 17698.jpg: 0 objects detected
# 📸 [214/1272] 17699.jpg: 1 objects detected
# 📸 [215/1272] 17702.jpg: 1 objects detected
# 📸 [216/1272] 17705.jpg: 1 objects detected
# 📸 [217/1272] 17707.jpg: 0 objects detected
# 📸 [218/1272] 17708.jpg: 1 objects detected
# 📸 [219/1272] 17709.jpg: 0 objects detected
# 📸 [220/1272] 17710.jpg: 1 objects detected
# 📸 [221/1272] 17711.jpg: 0 objects detected
# 📸 [222/1272] 17712.jpg: 0 objects detected
# 📸 [223/1272] 17713.jpg: 0 objects detected
# 📸 [224/1272] 17714.jpg: 0 objects detected
# 📸 [225/1272] 17715.jpg: 0 objects detected
# 📸 [226/1272] 17716.jpg: 0 objects detected
# 📸 [227/1272] 17717.jpg: 0 objects detected
# 📸 [228/1272] 17718.jpg: 1 objects detected
# 📸 [229/1272] 17719.jpg: 0 objects detected
# 📸 [230/1272] 17720.jpg: 0 objects detected
# 📸 [231/1272] 17721.jpg: 0 objects detected
# 📸 [232/1272] 17722.jpg: 1 objects detected
# 📸 [233/1272] 17723.jpg: 0 objects detected
# 📸 [234/1272] 17724.jpg: 1 objects detected
# 📸 [235/1272] 17725.jpg: 1 objects detected
# 📸 [236/1272] 17726.jpg: 1 objects detected
# 📸 [237/1272] 17727.jpg: 1 objects detected
# 📸 [238/1272] 17728.jpg: 0 objects detected
# 📸 [239/1272] 17729.jpg: 0 objects detected
# 📸 [240/1272] 17730.jpg: 0 objects detected
# 📸 [241/1272] 17731.jpg: 0 objects detected
# 📸 [242/1272] 17732.jpg: 0 objects detected
# 📸 [243/1272] 17733.jpg: 0 objects detected
# 📸 [244/1272] 17734.jpg: 1 objects detected
# 📸 [245/1272] 17735.jpg: 1 objects detected
# 📸 [246/1272] 17736.jpg: 1 objects detected
# 📸 [247/1272] 17737.jpg: 1 objects detected
# 📸 [248/1272] 17738.jpg: 0 objects detected
# 📸 [249/1272] 17739.jpg: 0 objects detected
# 📸 [250/1272] 17740.jpg: 0 objects detected
# 📸 [251/1272] 17741.jpg: 1 objects detected
# 📸 [252/1272] 17742.jpg: 0 objects detected
# 📸 [253/1272] 17743.jpg: 0 objects detected
# 📸 [254/1272] 17744.jpg: 1 objects detected
# 📸 [255/1272] 17745.jpg: 1 objects detected
# 📸 [256/1272] 17746.jpg: 0 objects detected
# 📸 [257/1272] 17747.jpg: 1 objects detected
# 📸 [258/1272] 17748.jpg: 0 objects detected
# 📸 [259/1272] 17749.jpg: 0 objects detected
# 📸 [260/1272] 17750.jpg: 0 objects detected
# 📸 [261/1272] 17751.jpg: 0 objects detected
# 📸 [262/1272] 17752.jpg: 1 objects detected
# 📸 [263/1272] 17753.jpg: 0 objects detected
# 📸 [264/1272] 17754.jpg: 1 objects detected
# 📸 [265/1272] 17755.jpg: 0 objects detected
# 📸 [266/1272] 17756.jpg: 0 objects detected
# 📸 [267/1272] 17757.jpg: 0 objects detected
# 📸 [268/1272] 17758.jpg: 0 objects detected
# 📸 [269/1272] 17759.jpg: 0 objects detected
# 📸 [270/1272] 17760.jpg: 1 objects detected
# 📸 [271/1272] 17762.jpg: 0 objects detected
# 📸 [272/1272] 17763.jpg: 1 objects detected
# 📸 [273/1272] 17764.jpg: 1 objects detected
# 📸 [274/1272] 17765.jpg: 0 objects detected
# 📸 [275/1272] 17766.jpg: 0 objects detected
# 📸 [276/1272] 17767.jpg: 0 objects detected
# 📸 [277/1272] 17768.jpg: 0 objects detected
# 📸 [278/1272] 17769.jpg: 0 objects detected
# 📸 [279/1272] 17770.jpg: 1 objects detected
# 📸 [280/1272] 17771.jpg: 1 objects detected
# 📸 [281/1272] 17772.jpg: 0 objects detected
# 📸 [282/1272] 17773.jpg: 1 objects detected
# 📸 [283/1272] 17774.jpg: 1 objects detected
# 📸 [284/1272] 17775.jpg: 0 objects detected
# 📸 [285/1272] 17776.jpg: 1 objects detected
# 📸 [286/1272] 17777.jpg: 1 objects detected
# 📸 [287/1272] 17778.jpg: 1 objects detected
# 📸 [288/1272] 17779.jpg: 0 objects detected
# 📸 [289/1272] 17780.jpg: 0 objects detected
# 📸 [290/1272] 17781.jpg: 0 objects detected
# 📸 [291/1272] 17782.jpg: 0 objects detected
# 📸 [292/1272] 17783.jpg: 0 objects detected
# 📸 [293/1272] 17784.jpg: 0 objects detected
# 📸 [294/1272] 17785.jpg: 0 objects detected
# 📸 [295/1272] 17786.jpg: 1 objects detected
# 📸 [296/1272] 17787.jpg: 1 objects detected
# 📸 [297/1272] 17788.jpg: 0 objects detected
# 📸 [298/1272] 17789.jpg: 0 objects detected
# 📸 [299/1272] 17791.jpg: 0 objects detected
# 📸 [300/1272] 17792.jpg: 0 objects detected
# 📸 [301/1272] 17793.jpg: 0 objects detected
# 📸 [302/1272] 17794.jpg: 1 objects detected
# 📸 [303/1272] 17795.jpg: 1 objects detected
# 📸 [304/1272] 17796.jpg: 1 objects detected
# 📸 [305/1272] 17797.jpg: 0 objects detected
# 📸 [306/1272] 17798.jpg: 0 objects detected
# 📸 [307/1272] 17799.jpg: 1 objects detected
# 📸 [308/1272] 17800.jpg: 1 objects detected
# 📸 [309/1272] 17801.jpg: 1 objects detected
# 📸 [310/1272] 17802.jpg: 0 objects detected
# 📸 [311/1272] 17803.jpg: 0 objects detected
# 📸 [312/1272] 17804.jpg: 0 objects detected
# 📸 [313/1272] 17806.jpg: 0 objects detected
# 📸 [314/1272] 17807.jpg: 0 objects detected
# 📸 [315/1272] 17808.jpg: 0 objects detected
# 📸 [316/1272] 17809.jpg: 1 objects detected
# 📸 [317/1272] 17810.jpg: 0 objects detected
# 📸 [318/1272] 17811.jpg: 1 objects detected
# 📸 [319/1272] 17812.jpg: 0 objects detected
# 📸 [320/1272] 17813.jpg: 0 objects detected
# 📸 [321/1272] 17814.jpg: 0 objects detected
# 📸 [322/1272] 17815.jpg: 0 objects detected
# 📸 [323/1272] 17816.jpg: 0 objects detected
# 📸 [324/1272] 17817.jpg: 1 objects detected
# 📸 [325/1272] 17818.jpg: 1 objects detected
# 📸 [326/1272] 17819.jpg: 0 objects detected
# 📸 [327/1272] 17820.jpg: 0 objects detected
# 📸 [328/1272] 17821.jpg: 0 objects detected
# 📸 [329/1272] 17822.jpg: 0 objects detected
# 📸 [330/1272] 17823.jpg: 1 objects detected
# 📸 [331/1272] 17825.jpg: 0 objects detected
# 📸 [332/1272] 17826.jpg: 1 objects detected
# 📸 [333/1272] 17827.jpg: 1 objects detected
# 📸 [334/1272] 17828.jpg: 0 objects detected
# 📸 [335/1272] 17829.jpg: 0 objects detected
# 📸 [336/1272] 17830.jpg: 0 objects detected
# 📸 [337/1272] 17831.jpg: 0 objects detected
# 📸 [338/1272] 17832.jpg: 0 objects detected
# 📸 [339/1272] 17833.jpg: 1 objects detected
# 📸 [340/1272] 17834.jpg: 0 objects detected
# 📸 [341/1272] 17835.jpg: 0 objects detected
# 📸 [342/1272] 17836.jpg: 0 objects detected
# 📸 [343/1272] 17837.jpg: 0 objects detected
# 📸 [344/1272] 17838.jpg: 0 objects detected
# 📸 [345/1272] 17839.jpg: 0 objects detected
# 📸 [346/1272] 17840.jpg: 0 objects detected
# 📸 [347/1272] 17842.jpg: 1 objects detected
# 📸 [348/1272] 17843.jpg: 0 objects detected
# 📸 [349/1272] 17844.jpg: 0 objects detected
# 📸 [350/1272] 17845.jpg: 1 objects detected
# 📸 [351/1272] 17847.jpg: 0 objects detected
# 📸 [352/1272] 17848.jpg: 0 objects detected
# 📸 [353/1272] 17849.jpg: 0 objects detected
# 📸 [354/1272] 17850.jpg: 1 objects detected
# 📸 [355/1272] 17852.jpg: 0 objects detected
# 📸 [356/1272] 17854.jpg: 0 objects detected
# 📸 [357/1272] 17855.jpg: 0 objects detected
# 📸 [358/1272] 17856.jpg: 1 objects detected
# 📸 [359/1272] 17857.jpg: 0 objects detected
# 📸 [360/1272] 17858.jpg: 1 objects detected
# 📸 [361/1272] 17859.jpg: 0 objects detected
# 📸 [362/1272] 17860.jpg: 0 objects detected
# 📸 [363/1272] 17861.jpg: 0 objects detected
# 📸 [364/1272] 17862.jpg: 0 objects detected
# 📸 [365/1272] 17863.jpg: 0 objects detected
# 📸 [366/1272] 17864.jpg: 0 objects detected
# 📸 [367/1272] 17865.jpg: 0 objects detected
# 📸 [368/1272] 17866.jpg: 0 objects detected
# 📸 [369/1272] 17867.jpg: 0 objects detected
# 📸 [370/1272] 17868.jpg: 0 objects detected
# 📸 [371/1272] 17869.jpg: 0 objects detected
# 📸 [372/1272] 17870.jpg: 1 objects detected
# 📸 [373/1272] 17871.jpg: 0 objects detected
# 📸 [374/1272] 17872.jpg: 0 objects detected
# 📸 [375/1272] 17873.jpg: 0 objects detected
# 📸 [376/1272] 17874.jpg: 1 objects detected
# 📸 [377/1272] 17875.jpg: 0 objects detected
# 📸 [378/1272] 17876.jpg: 0 objects detected
# 📸 [379/1272] 17877.jpg: 1 objects detected
# 📸 [380/1272] 17878.jpg: 0 objects detected
# 📸 [381/1272] 17879.jpg: 0 objects detected
# 📸 [382/1272] 17880.jpg: 0 objects detected
# 📸 [383/1272] 17881.jpg: 1 objects detected
# 📸 [384/1272] 17882.jpg: 0 objects detected
# 📸 [385/1272] 17883.jpg: 0 objects detected
# 📸 [386/1272] 17884.jpg: 0 objects detected
# 📸 [387/1272] 17885.jpg: 0 objects detected
# 📸 [388/1272] 17886.jpg: 0 objects detected
# 📸 [389/1272] 17887.jpg: 0 objects detected
# 📸 [390/1272] 17888.jpg: 0 objects detected
# 📸 [391/1272] 17889.jpg: 1 objects detected
# 📸 [392/1272] 17890.jpg: 0 objects detected
# 📸 [393/1272] 17891.jpg: 0 objects detected
# 📸 [394/1272] 17892.jpg: 0 objects detected
# 📸 [395/1272] 17893.jpg: 0 objects detected
# 📸 [396/1272] 17894.jpg: 0 objects detected
# 📸 [397/1272] 17895.jpg: 0 objects detected
# 📸 [398/1272] 17896.jpg: 0 objects detected
# 📸 [399/1272] 17897.jpg: 1 objects detected
# 📸 [400/1272] 17898.jpg: 1 objects detected
# 📸 [401/1272] 17899.jpg: 0 objects detected
# 📸 [402/1272] 17900.jpg: 1 objects detected
# 📸 [403/1272] 17901.jpg: 0 objects detected
# 📸 [404/1272] 17902.jpg: 0 objects detected
# 📸 [405/1272] 17903.jpg: 0 objects detected
# 📸 [406/1272] 17904.jpg: 1 objects detected
# 📸 [407/1272] 17905.jpg: 0 objects detected
# 📸 [408/1272] 17906.jpg: 0 objects detected
# 📸 [409/1272] 17907.jpg: 0 objects detected
# 📸 [410/1272] 17909.jpg: 0 objects detected
# 📸 [411/1272] 17910.jpg: 1 objects detected
# 📸 [412/1272] 17911.jpg: 1 objects detected
# 📸 [413/1272] 17912.jpg: 1 objects detected
# 📸 [414/1272] 17913.jpg: 0 objects detected
# 📸 [415/1272] 17914.jpg: 1 objects detected
# 📸 [416/1272] 17917.jpg: 1 objects detected
# 📸 [417/1272] 17920.jpg: 1 objects detected
# 📸 [418/1272] 17921.jpg: 0 objects detected
# 📸 [419/1272] 17922.jpg: 0 objects detected
# 📸 [420/1272] 17923.jpg: 0 objects detected
# 📸 [421/1272] 17924.jpg: 0 objects detected
# 📸 [422/1272] 17925.jpg: 0 objects detected
# 📸 [423/1272] 17926.jpg: 0 objects detected
# 📸 [424/1272] 17927.jpg: 0 objects detected
# 📸 [425/1272] 17928.jpg: 1 objects detected
# 📸 [426/1272] 17929.jpg: 0 objects detected
# 📸 [427/1272] 17930.jpg: 0 objects detected
# 📸 [428/1272] 17931.jpg: 0 objects detected
# 📸 [429/1272] 17932.jpg: 1 objects detected
# 📸 [430/1272] 17933.jpg: 1 objects detected
# 📸 [431/1272] 17934.jpg: 1 objects detected
# 📸 [432/1272] 17935.jpg: 1 objects detected
# 📸 [433/1272] 17936.jpg: 0 objects detected
# 📸 [434/1272] 17937.jpg: 0 objects detected
# 📸 [435/1272] 17938.jpg: 0 objects detected
# 📸 [436/1272] 17939.jpg: 0 objects detected
# 📸 [437/1272] 17940.jpg: 0 objects detected
# 📸 [438/1272] 17941.jpg: 1 objects detected
# 📸 [439/1272] 17942.jpg: 0 objects detected
# 📸 [440/1272] 17943.jpg: 0 objects detected
# 📸 [441/1272] 17944.jpg: 0 objects detected
# 📸 [442/1272] 17945.jpg: 0 objects detected
# 📸 [443/1272] 17946.jpg: 1 objects detected
# 📸 [444/1272] 17948.jpg: 0 objects detected
# 📸 [445/1272] 17950.jpg: 1 objects detected
# 📸 [446/1272] 17951.jpg: 0 objects detected
# 📸 [447/1272] 17952.jpg: 0 objects detected
# 📸 [448/1272] 17953.jpg: 0 objects detected
# 📸 [449/1272] 17955.jpg: 0 objects detected
# 📸 [450/1272] 17956.jpg: 0 objects detected
# 📸 [451/1272] 17957.jpg: 0 objects detected
# 📸 [452/1272] 17958.jpg: 0 objects detected
# 📸 [453/1272] 17959.jpg: 0 objects detected
# 📸 [454/1272] 17960.jpg: 1 objects detected
# 📸 [455/1272] 17961.jpg: 0 objects detected
# 📸 [456/1272] 17962.jpg: 1 objects detected
# 📸 [457/1272] 17963.jpg: 1 objects detected
# 📸 [458/1272] 17964.jpg: 0 objects detected
# 📸 [459/1272] 17965.jpg: 0 objects detected
# 📸 [460/1272] 17966.jpg: 0 objects detected
# 📸 [461/1272] 17967.jpg: 1 objects detected
# 📸 [462/1272] 17968.jpg: 0 objects detected
# 📸 [463/1272] 17969.jpg: 1 objects detected
# 📸 [464/1272] 17970.jpg: 1 objects detected
# 📸 [465/1272] 17971.jpg: 0 objects detected
# 📸 [466/1272] 17972.jpg: 1 objects detected
# 📸 [467/1272] 17973.jpg: 0 objects detected
# 📸 [468/1272] 17974.jpg: 1 objects detected
# 📸 [469/1272] 17975.jpg: 0 objects detected
# 📸 [470/1272] 17976.jpg: 1 objects detected
# 📸 [471/1272] 17977.jpg: 1 objects detected
# 📸 [472/1272] 17978.jpg: 0 objects detected
# 📸 [473/1272] 17979.jpg: 1 objects detected
# 📸 [474/1272] 17980.jpg: 1 objects detected
# 📸 [475/1272] 17981.jpg: 0 objects detected
# 📸 [476/1272] 17982.jpg: 0 objects detected
# 📸 [477/1272] 17983.jpg: 1 objects detected
# 📸 [478/1272] 17984.jpg: 1 objects detected
# 📸 [479/1272] 17985.jpg: 1 objects detected
# 📸 [480/1272] 17986.jpg: 1 objects detected
# 📸 [481/1272] 17987.jpg: 1 objects detected
# 📸 [482/1272] 17988.jpg: 0 objects detected
# 📸 [483/1272] 17989.jpg: 1 objects detected
# 📸 [484/1272] 17990.jpg: 0 objects detected
# 📸 [485/1272] 17991.jpg: 0 objects detected
# 📸 [486/1272] 17992.jpg: 0 objects detected
# 📸 [487/1272] 17993.jpg: 0 objects detected
# 📸 [488/1272] 17994.jpg: 1 objects detected
# 📸 [489/1272] 17995.jpg: 0 objects detected
# 📸 [490/1272] 17996.jpg: 1 objects detected
# 📸 [491/1272] 17997.jpg: 0 objects detected
# 📸 [492/1272] 17998.jpg: 0 objects detected
# 📸 [493/1272] 17999.jpg: 1 objects detected
# 📸 [494/1272] 18000.jpg: 0 objects detected
# 📸 [495/1272] 18001.jpg: 0 objects detected
# 📸 [496/1272] 18002.jpg: 0 objects detected
# 📸 [497/1272] 18003.jpg: 0 objects detected
# 📸 [498/1272] 18004.jpg: 0 objects detected
# 📸 [499/1272] 18005.jpg: 0 objects detected
# 📸 [500/1272] 18006.jpg: 0 objects detected
# 📸 [501/1272] 18007.jpg: 0 objects detected
# 📸 [502/1272] 18008.jpg: 1 objects detected
# 📸 [503/1272] 18009.jpg: 0 objects detected
# 📸 [504/1272] 18010.jpg: 0 objects detected
# 📸 [505/1272] 18011.jpg: 0 objects detected
# 📸 [506/1272] 18012.jpg: 0 objects detected
# 📸 [507/1272] 18013.jpg: 0 objects detected
# 📸 [508/1272] 18014.jpg: 0 objects detected
# 📸 [509/1272] 18015.jpg: 0 objects detected
# 📸 [510/1272] 18016.jpg: 0 objects detected
# 📸 [511/1272] 18017.jpg: 0 objects detected
# 📸 [512/1272] 18018.jpg: 0 objects detected
# 📸 [513/1272] 18019.jpg: 0 objects detected
# 📸 [514/1272] 18020.jpg: 0 objects detected
# 📸 [515/1272] 18022.jpg: 0 objects detected
# 📸 [516/1272] 18023.jpg: 0 objects detected
# 📸 [517/1272] 18024.jpg: 1 objects detected
# 📸 [518/1272] 18025.jpg: 0 objects detected
# 📸 [519/1272] 18026.jpg: 1 objects detected
# 📸 [520/1272] 18027.jpg: 0 objects detected
# 📸 [521/1272] 18028.jpg: 0 objects detected
# 📸 [522/1272] 18029.jpg: 1 objects detected
# 📸 [523/1272] 18030.jpg: 0 objects detected
# 📸 [524/1272] 18031.jpg: 1 objects detected
# 📸 [525/1272] 18032.jpg: 0 objects detected
# 📸 [526/1272] 18033.jpg: 0 objects detected
# 📸 [527/1272] 18035.jpg: 0 objects detected
# 📸 [528/1272] 18036.jpg: 0 objects detected
# 📸 [529/1272] 18038.jpg: 0 objects detected
# 📸 [530/1272] 18039.jpg: 1 objects detected
# 📸 [531/1272] 18040.jpg: 1 objects detected
# 📸 [532/1272] 18041.jpg: 0 objects detected
# 📸 [533/1272] 18042.jpg: 0 objects detected
# 📸 [534/1272] 18043.jpg: 0 objects detected
# 📸 [535/1272] 18044.jpg: 1 objects detected
# 📸 [536/1272] 18045.jpg: 1 objects detected
# 📸 [537/1272] 18046.jpg: 0 objects detected
# 📸 [538/1272] 18047.jpg: 1 objects detected
# 📸 [539/1272] 18048.jpg: 1 objects detected
# 📸 [540/1272] 18049.jpg: 0 objects detected
# 📸 [541/1272] 18050.jpg: 1 objects detected
# 📸 [542/1272] 18051.jpg: 1 objects detected
# 📸 [543/1272] 18052.jpg: 1 objects detected
# 📸 [544/1272] 18053.jpg: 0 objects detected
# 📸 [545/1272] 18054.jpg: 0 objects detected
# 📸 [546/1272] 18055.jpg: 0 objects detected
# 📸 [547/1272] 18057.jpg: 0 objects detected
# 📸 [548/1272] 18058.jpg: 0 objects detected
# 📸 [549/1272] 18059.jpg: 0 objects detected
# 📸 [550/1272] 18060.jpg: 0 objects detected
# 📸 [551/1272] 18061.jpg: 0 objects detected
# 📸 [552/1272] 18062.jpg: 0 objects detected
# 📸 [553/1272] 18063.jpg: 1 objects detected
# 📸 [554/1272] 18064.jpg: 0 objects detected
# 📸 [555/1272] 18065.jpg: 0 objects detected
# 📸 [556/1272] 18066.jpg: 0 objects detected
# 📸 [557/1272] 18067.jpg: 0 objects detected
# 📸 [558/1272] 18068.jpg: 0 objects detected
# 📸 [559/1272] 18069.jpg: 0 objects detected
# 📸 [560/1272] 18070.jpg: 0 objects detected
# 📸 [561/1272] 18071.jpg: 0 objects detected
# 📸 [562/1272] 18072.jpg: 0 objects detected
# 📸 [563/1272] 18073.jpg: 0 objects detected
# 📸 [564/1272] 18074.jpg: 0 objects detected
# 📸 [565/1272] 18075.jpg: 0 objects detected
# 📸 [566/1272] 18077.jpg: 1 objects detected
# 📸 [567/1272] 18078.jpg: 0 objects detected
# 📸 [568/1272] 18079.jpg: 0 objects detected
# 📸 [569/1272] 18080.jpg: 1 objects detected
# 📸 [570/1272] 18081.jpg: 1 objects detected
# 📸 [571/1272] 18082.jpg: 1 objects detected
# 📸 [572/1272] 18083.jpg: 1 objects detected
# 📸 [573/1272] 18084.jpg: 1 objects detected
# 📸 [574/1272] 18085.jpg: 0 objects detected
# 📸 [575/1272] 18086.jpg: 0 objects detected
# 📸 [576/1272] 18087.jpg: 0 objects detected
# 📸 [577/1272] 18088.jpg: 0 objects detected
# 📸 [578/1272] 18089.jpg: 1 objects detected
# 📸 [579/1272] 18091.jpg: 0 objects detected
# 📸 [580/1272] 18092.jpg: 1 objects detected
# 📸 [581/1272] 18095.jpg: 1 objects detected
# 📸 [582/1272] 18098.jpg: 0 objects detected
# 📸 [583/1272] 18099.jpg: 0 objects detected
# 📸 [584/1272] 18100.jpg: 0 objects detected
# 📸 [585/1272] 18101.jpg: 0 objects detected
# 📸 [586/1272] 18102.jpg: 0 objects detected
# 📸 [587/1272] 18103.jpg: 0 objects detected
# 📸 [588/1272] 18104.jpg: 0 objects detected
# 📸 [589/1272] 18105.jpg: 0 objects detected
# 📸 [590/1272] 18106.jpg: 0 objects detected
# 📸 [591/1272] 18107.jpg: 1 objects detected
# 📸 [592/1272] 18108.jpg: 0 objects detected
# 📸 [593/1272] 18109.jpg: 0 objects detected
# 📸 [594/1272] 18110.jpg: 1 objects detected
# 📸 [595/1272] 18111.jpg: 0 objects detected
# 📸 [596/1272] 18112.jpg: 0 objects detected
# 📸 [597/1272] 18113.jpg: 0 objects detected
# 📸 [598/1272] 18114.jpg: 0 objects detected
# 📸 [599/1272] 18115.jpg: 0 objects detected
# 📸 [600/1272] 18116.jpg: 1 objects detected
# 📸 [601/1272] 18121.jpg: 0 objects detected
# 📸 [602/1272] 18122.jpg: 0 objects detected
# 📸 [603/1272] 18123.jpg: 0 objects detected
# 📸 [604/1272] 18124.jpg: 0 objects detected
# 📸 [605/1272] 18125.jpg: 0 objects detected
# 📸 [606/1272] 18126.jpg: 1 objects detected
# 📸 [607/1272] 18128.jpg: 0 objects detected
# 📸 [608/1272] 18129.jpg: 0 objects detected
# 📸 [609/1272] 18130.jpg: 1 objects detected
# 📸 [610/1272] 18131.jpg: 0 objects detected
# 📸 [611/1272] 18132.jpg: 1 objects detected
# 📸 [612/1272] 18133.jpg: 1 objects detected
# 📸 [613/1272] 18134.jpg: 1 objects detected
# 📸 [614/1272] 18135.jpg: 0 objects detected
# 📸 [615/1272] 18136.jpg: 0 objects detected
# 📸 [616/1272] 18137.jpg: 1 objects detected
# 📸 [617/1272] 18138.jpg: 0 objects detected
# 📸 [618/1272] 18139.jpg: 1 objects detected
# 📸 [619/1272] 18140.jpg: 0 objects detected
# 📸 [620/1272] 18141.jpg: 0 objects detected
# 📸 [621/1272] 18142.jpg: 0 objects detected
# 📸 [622/1272] 18143.jpg: 0 objects detected
# 📸 [623/1272] 18144.jpg: 0 objects detected
# 📸 [624/1272] 18145.jpg: 1 objects detected
# 📸 [625/1272] 18146.jpg: 1 objects detected
# 📸 [626/1272] 18147.jpg: 1 objects detected
# 📸 [627/1272] 18148.jpg: 0 objects detected
# 📸 [628/1272] 18149.jpg: 0 objects detected
# 📸 [629/1272] 18150.jpg: 0 objects detected
# 📸 [630/1272] 18151.jpg: 1 objects detected
# 📸 [631/1272] 18152.jpg: 1 objects detected
# 📸 [632/1272] 18153.jpg: 0 objects detected
# 📸 [633/1272] 18154.jpg: 0 objects detected
# 📸 [634/1272] 18155.jpg: 1 objects detected
# 📸 [635/1272] 18156.jpg: 0 objects detected
# 📸 [636/1272] 18157.jpg: 0 objects detected
# 📸 [637/1272] 18158.jpg: 0 objects detected
# 📸 [638/1272] 18162.jpg: 0 objects detected
# 📸 [639/1272] 18163.jpg: 0 objects detected
# 📸 [640/1272] 18164.jpg: 1 objects detected
# 📸 [641/1272] 18165.jpg: 0 objects detected
# 📸 [642/1272] 18166.jpg: 0 objects detected
# 📸 [643/1272] 18167.jpg: 0 objects detected
# 📸 [644/1272] 18168.jpg: 0 objects detected
# 📸 [645/1272] 18169.jpg: 1 objects detected
# 📸 [646/1272] 18171.jpg: 0 objects detected
# 📸 [647/1272] 18173.jpg: 0 objects detected
# 📸 [648/1272] 18174.jpg: 0 objects detected
# 📸 [649/1272] 18175.jpg: 0 objects detected
# 📸 [650/1272] 18176.jpg: 0 objects detected
# 📸 [651/1272] 18177.jpg: 1 objects detected
# 📸 [652/1272] 18178.jpg: 0 objects detected
# 📸 [653/1272] 18179.jpg: 0 objects detected
# 📸 [654/1272] 18180.jpg: 0 objects detected
# 📸 [655/1272] 18181.jpg: 0 objects detected
# 📸 [656/1272] 18183.jpg: 0 objects detected
# 📸 [657/1272] 18185.jpg: 1 objects detected
# 📸 [658/1272] 18186.jpg: 0 objects detected
# 📸 [659/1272] 18187.jpg: 0 objects detected
# 📸 [660/1272] 18188.jpg: 0 objects detected
# 📸 [661/1272] 18189.jpg: 0 objects detected
# 📸 [662/1272] 18190.jpg: 0 objects detected
# 📸 [663/1272] 18191.jpg: 0 objects detected
# 📸 [664/1272] 18192.jpg: 0 objects detected
# 📸 [665/1272] 18193.jpg: 0 objects detected
# 📸 [666/1272] 18194.jpg: 1 objects detected
# 📸 [667/1272] 18195.jpg: 0 objects detected
# 📸 [668/1272] 18196.jpg: 1 objects detected
# 📸 [669/1272] 18197.jpg: 0 objects detected
# 📸 [670/1272] 18198.jpg: 0 objects detected
# 📸 [671/1272] 18199.jpg: 1 objects detected
# 📸 [672/1272] 18200.jpg: 1 objects detected
# 📸 [673/1272] 18201.jpg: 0 objects detected
# 📸 [674/1272] 18202.jpg: 0 objects detected
# 📸 [675/1272] 18203.jpg: 0 objects detected
# 📸 [676/1272] 18204.jpg: 0 objects detected
# 📸 [677/1272] 18206.jpg: 1 objects detected
# 📸 [678/1272] 18207.jpg: 1 objects detected
# 📸 [679/1272] 18208.jpg: 1 objects detected
# 📸 [680/1272] 18209.jpg: 0 objects detected
# 📸 [681/1272] 18210.jpg: 0 objects detected
# 📸 [682/1272] 18211.jpg: 1 objects detected
# 📸 [683/1272] 18212.jpg: 0 objects detected
# 📸 [684/1272] 18213.jpg: 0 objects detected
# 📸 [685/1272] 18214.jpg: 0 objects detected
# 📸 [686/1272] 18215.jpg: 0 objects detected
# 📸 [687/1272] 18216.jpg: 0 objects detected
# 📸 [688/1272] 18218.jpg: 0 objects detected
# 📸 [689/1272] 18219.jpg: 0 objects detected
# 📸 [690/1272] 18220.jpg: 0 objects detected
# 📸 [691/1272] 18221.jpg: 1 objects detected
# 📸 [692/1272] 18222.jpg: 1 objects detected
# 📸 [693/1272] 18223.jpg: 0 objects detected
# 📸 [694/1272] 18224.jpg: 0 objects detected
# 📸 [695/1272] 18225.jpg: 0 objects detected
# 📸 [696/1272] 18226.jpg: 0 objects detected
# 📸 [697/1272] 18227.jpg: 1 objects detected
# 📸 [698/1272] 18228.jpg: 1 objects detected
# 📸 [699/1272] 18229.jpg: 0 objects detected
# 📸 [700/1272] 18230.jpg: 0 objects detected
# 📸 [701/1272] 18231.jpg: 0 objects detected
# 📸 [702/1272] 18232.jpg: 0 objects detected
# 📸 [703/1272] 18233.jpg: 0 objects detected
# 📸 [704/1272] 18234.jpg: 0 objects detected
# 📸 [705/1272] 18235.jpg: 0 objects detected
# 📸 [706/1272] 18236.jpg: 0 objects detected
# 📸 [707/1272] 18237.jpg: 0 objects detected
# 📸 [708/1272] 18238.jpg: 1 objects detected
# 📸 [709/1272] 18239.jpg: 1 objects detected
# 📸 [710/1272] 18240.jpg: 0 objects detected
# 📸 [711/1272] 18241.jpg: 0 objects detected
# 📸 [712/1272] 18242.jpg: 0 objects detected
# 📸 [713/1272] 18243.jpg: 0 objects detected
# 📸 [714/1272] 18244.jpg: 0 objects detected
# 📸 [715/1272] 18245.jpg: 0 objects detected
# 📸 [716/1272] 18247.jpg: 1 objects detected
# 📸 [717/1272] 18248.jpg: 1 objects detected
# 📸 [718/1272] 18249.jpg: 0 objects detected
# 📸 [719/1272] 18250.jpg: 1 objects detected
# 📸 [720/1272] 18251.jpg: 0 objects detected
# 📸 [721/1272] 18252.jpg: 0 objects detected
# 📸 [722/1272] 18253.jpg: 0 objects detected
# 📸 [723/1272] 18254.jpg: 0 objects detected
# 📸 [724/1272] 18255.jpg: 1 objects detected
# 📸 [725/1272] 18257.jpg: 0 objects detected
# 📸 [726/1272] 18259.jpg: 1 objects detected
# 📸 [727/1272] 18260.jpg: 0 objects detected
# 📸 [728/1272] 18261.jpg: 0 objects detected
# 📸 [729/1272] 18262.jpg: 0 objects detected
# 📸 [730/1272] 18263.jpg: 0 objects detected
# 📸 [731/1272] 18264.jpg: 0 objects detected
# 📸 [732/1272] 18265.jpg: 1 objects detected
# 📸 [733/1272] 18266.jpg: 0 objects detected
# 📸 [734/1272] 18267.jpg: 0 objects detected
# 📸 [735/1272] 18268.jpg: 0 objects detected
# 📸 [736/1272] 18269.jpg: 0 objects detected
# 📸 [737/1272] 18270.jpg: 0 objects detected
# 📸 [738/1272] 18271.jpg: 0 objects detected
# 📸 [739/1272] 18272.jpg: 0 objects detected
# 📸 [740/1272] 18273.jpg: 0 objects detected
# 📸 [741/1272] 18274.jpg: 0 objects detected
# 📸 [742/1272] 18276.jpg: 0 objects detected
# 📸 [743/1272] 18277.jpg: 0 objects detected
# 📸 [744/1272] 18278.jpg: 0 objects detected
# 📸 [745/1272] 18279.jpg: 0 objects detected
# 📸 [746/1272] 18280.jpg: 0 objects detected
# 📸 [747/1272] 18281.jpg: 0 objects detected
# 📸 [748/1272] 18282.jpg: 1 objects detected
# 📸 [749/1272] 18283.jpg: 0 objects detected
# 📸 [750/1272] 18284.jpg: 0 objects detected
# 📸 [751/1272] 18285.jpg: 0 objects detected
# 📸 [752/1272] 18287.jpg: 1 objects detected
# 📸 [753/1272] 18288.jpg: 0 objects detected
# 📸 [754/1272] 18289.jpg: 0 objects detected
# 📸 [755/1272] 18290.jpg: 0 objects detected
# 📸 [756/1272] 18291.jpg: 0 objects detected
# 📸 [757/1272] 18293.jpg: 0 objects detected
# 📸 [758/1272] 18294.jpg: 0 objects detected
# 📸 [759/1272] 18295.jpg: 0 objects detected
# 📸 [760/1272] 18296.jpg: 0 objects detected
# 📸 [761/1272] 18297.jpg: 1 objects detected
# 📸 [762/1272] 18298.jpg: 0 objects detected
# 📸 [763/1272] 18299.jpg: 0 objects detected
# 📸 [764/1272] 18300.jpg: 0 objects detected
# 📸 [765/1272] 18301.jpg: 1 objects detected
# 📸 [766/1272] 18302.jpg: 1 objects detected
# 📸 [767/1272] 18303.jpg: 1 objects detected
# 📸 [768/1272] 18304.jpg: 0 objects detected
# 📸 [769/1272] 18305.jpg: 0 objects detected
# 📸 [770/1272] 18306.jpg: 0 objects detected
# 📸 [771/1272] 18307.jpg: 0 objects detected
# 📸 [772/1272] 18308.jpg: 0 objects detected
# 📸 [773/1272] 18309.jpg: 0 objects detected
# 📸 [774/1272] 18310.jpg: 0 objects detected
# 📸 [775/1272] 18311.jpg: 0 objects detected
# 📸 [776/1272] 18312.jpg: 0 objects detected
# 📸 [777/1272] 18313.jpg: 1 objects detected
# 📸 [778/1272] 18314.jpg: 0 objects detected
# 📸 [779/1272] 18315.jpg: 0 objects detected
# 📸 [780/1272] 18316.jpg: 0 objects detected
# 📸 [781/1272] 18317.jpg: 1 objects detected
# 📸 [782/1272] 18318.jpg: 0 objects detected
# 📸 [783/1272] 18319.jpg: 1 objects detected
# 📸 [784/1272] 18320.jpg: 0 objects detected
# 📸 [785/1272] 18321.jpg: 0 objects detected
# 📸 [786/1272] 18322.jpg: 1 objects detected
# 📸 [787/1272] 18323.jpg: 0 objects detected
# 📸 [788/1272] 18324.jpg: 0 objects detected
# 📸 [789/1272] 18326.jpg: 1 objects detected
# 📸 [790/1272] 18327.jpg: 0 objects detected
# 📸 [791/1272] 18328.jpg: 1 objects detected
# 📸 [792/1272] 18329.jpg: 0 objects detected
# 📸 [793/1272] 18330.jpg: 0 objects detected
# 📸 [794/1272] 18332.jpg: 0 objects detected
# 📸 [795/1272] 18333.jpg: 1 objects detected
# 📸 [796/1272] 18334.jpg: 0 objects detected
# 📸 [797/1272] 18335.jpg: 0 objects detected
# 📸 [798/1272] 18336.jpg: 0 objects detected
# 📸 [799/1272] 18338.jpg: 1 objects detected
# 📸 [800/1272] 18339.jpg: 0 objects detected
# 📸 [801/1272] 18340.jpg: 1 objects detected
# 📸 [802/1272] 18341.jpg: 0 objects detected
# 📸 [803/1272] 18342.jpg: 0 objects detected
# 📸 [804/1272] 18343.jpg: 1 objects detected
# 📸 [805/1272] 18344.jpg: 0 objects detected
# 📸 [806/1272] 18345.jpg: 0 objects detected
# 📸 [807/1272] 18346.jpg: 0 objects detected
# 📸 [808/1272] 18347.jpg: 1 objects detected
# 📸 [809/1272] 18348.jpg: 0 objects detected
# 📸 [810/1272] 18349.jpg: 0 objects detected
# 📸 [811/1272] 18350.jpg: 0 objects detected
# 📸 [812/1272] 18351.jpg: 0 objects detected
# 📸 [813/1272] 18352.jpg: 1 objects detected
# 📸 [814/1272] 18353.jpg: 0 objects detected
# 📸 [815/1272] 18354.jpg: 0 objects detected
# 📸 [816/1272] 18355.jpg: 1 objects detected
# 📸 [817/1272] 18356.jpg: 0 objects detected
# 📸 [818/1272] 18357.jpg: 0 objects detected
# 📸 [819/1272] 18358.jpg: 0 objects detected
# 📸 [820/1272] 18359.jpg: 0 objects detected
# 📸 [821/1272] 18360.jpg: 0 objects detected
# 📸 [822/1272] 18361.jpg: 0 objects detected
# 📸 [823/1272] 18362.jpg: 1 objects detected
# 📸 [824/1272] 18363.jpg: 0 objects detected
# 📸 [825/1272] 18364.jpg: 0 objects detected
# 📸 [826/1272] 18365.jpg: 0 objects detected
# 📸 [827/1272] 18366.jpg: 0 objects detected
# 📸 [828/1272] 18367.jpg: 0 objects detected
# 📸 [829/1272] 18368.jpg: 0 objects detected
# 📸 [830/1272] 18369.jpg: 0 objects detected
# 📸 [831/1272] 18370.jpg: 0 objects detected
# 📸 [832/1272] 18371.jpg: 1 objects detected
# 📸 [833/1272] 18372.jpg: 0 objects detected
# 📸 [834/1272] 18373.jpg: 0 objects detected
# 📸 [835/1272] 18374.jpg: 0 objects detected
# 📸 [836/1272] 18375.jpg: 0 objects detected
# 📸 [837/1272] 18376.jpg: 0 objects detected
# 📸 [838/1272] 18377.jpg: 0 objects detected
# 📸 [839/1272] 18378.jpg: 0 objects detected
# 📸 [840/1272] 18379.jpg: 0 objects detected
# 📸 [841/1272] 18381.jpg: 1 objects detected
# 📸 [842/1272] 18382.jpg: 0 objects detected
# 📸 [843/1272] 18383.jpg: 1 objects detected
# 📸 [844/1272] 18384.jpg: 0 objects detected
# 📸 [845/1272] 18385.jpg: 0 objects detected
# 📸 [846/1272] 18386.jpg: 1 objects detected
# 📸 [847/1272] 18387.jpg: 0 objects detected
# 📸 [848/1272] 18388.jpg: 0 objects detected
# 📸 [849/1272] 18389.jpg: 1 objects detected
# 📸 [850/1272] 18390.jpg: 1 objects detected
# 📸 [851/1272] 18391.jpg: 1 objects detected
# 📸 [852/1272] 18392.jpg: 1 objects detected
# 📸 [853/1272] 18393.jpg: 1 objects detected
# 📸 [854/1272] 18394.jpg: 0 objects detected
# 📸 [855/1272] 18395.jpg: 1 objects detected
# 📸 [856/1272] 18396.jpg: 0 objects detected
# 📸 [857/1272] 18397.jpg: 0 objects detected
# 📸 [858/1272] 18398.jpg: 0 objects detected
# 📸 [859/1272] 18399.jpg: 0 objects detected
# 📸 [860/1272] 18400.jpg: 1 objects detected
# 📸 [861/1272] 18401.jpg: 0 objects detected
# 📸 [862/1272] 18402.jpg: 1 objects detected
# 📸 [863/1272] 18403.jpg: 0 objects detected
# 📸 [864/1272] 18404.jpg: 0 objects detected
# 📸 [865/1272] 18406.jpg: 1 objects detected
# 📸 [866/1272] 18407.jpg: 1 objects detected
# 📸 [867/1272] 18408.jpg: 0 objects detected
# 📸 [868/1272] 18409.jpg: 0 objects detected
# 📸 [869/1272] 18410.jpg: 0 objects detected
# 📸 [870/1272] 18411.jpg: 0 objects detected
# 📸 [871/1272] 18412.jpg: 0 objects detected
# 📸 [872/1272] 18413.jpg: 0 objects detected
# 📸 [873/1272] 18414.jpg: 0 objects detected
# 📸 [874/1272] 18415.jpg: 0 objects detected
# 📸 [875/1272] 18416.jpg: 1 objects detected
# 📸 [876/1272] 18417.jpg: 0 objects detected
# 📸 [877/1272] 18418.jpg: 1 objects detected
# 📸 [878/1272] 18419.jpg: 0 objects detected
# 📸 [879/1272] 18420.jpg: 1 objects detected
# 📸 [880/1272] 18421.jpg: 0 objects detected
# 📸 [881/1272] 18422.jpg: 0 objects detected
# 📸 [882/1272] 18423.jpg: 0 objects detected
# 📸 [883/1272] 18424.jpg: 0 objects detected
# 📸 [884/1272] 18425.jpg: 0 objects detected
# 📸 [885/1272] 18426.jpg: 1 objects detected
# 📸 [886/1272] 18427.jpg: 0 objects detected
# 📸 [887/1272] 18428.jpg: 0 objects detected
# 📸 [888/1272] 18429.jpg: 0 objects detected
# 📸 [889/1272] 18430.jpg: 0 objects detected
# 📸 [890/1272] 18431.jpg: 0 objects detected
# 📸 [891/1272] 18433.jpg: 0 objects detected
# 📸 [892/1272] 18434.jpg: 0 objects detected
# 📸 [893/1272] 18435.jpg: 1 objects detected
# 📸 [894/1272] 18436.jpg: 0 objects detected
# 📸 [895/1272] 18437.jpg: 0 objects detected
# 📸 [896/1272] 18438.jpg: 0 objects detected
# 📸 [897/1272] 18439.jpg: 0 objects detected
# 📸 [898/1272] 18440.jpg: 0 objects detected
# 📸 [899/1272] 18441.jpg: 0 objects detected
# 📸 [900/1272] 18442.jpg: 0 objects detected
# 📸 [901/1272] 18443.jpg: 1 objects detected
# 📸 [902/1272] 18445.jpg: 0 objects detected
# 📸 [903/1272] 18446.jpg: 0 objects detected
# 📸 [904/1272] 18448.jpg: 1 objects detected
# 📸 [905/1272] 18449.jpg: 0 objects detected
# 📸 [906/1272] 18450.jpg: 0 objects detected
# 📸 [907/1272] 18451.jpg: 0 objects detected
# 📸 [908/1272] 18452.jpg: 1 objects detected
# 📸 [909/1272] 18453.jpg: 0 objects detected
# 📸 [910/1272] 18454.jpg: 1 objects detected
# 📸 [911/1272] 18455.jpg: 1 objects detected
# 📸 [912/1272] 18456.jpg: 1 objects detected
# 📸 [913/1272] 18457.jpg: 1 objects detected
# 📸 [914/1272] 18458.jpg: 1 objects detected
# 📸 [915/1272] 18459.jpg: 0 objects detected
# 📸 [916/1272] 18460.jpg: 1 objects detected
# 📸 [917/1272] 18461.jpg: 0 objects detected
# 📸 [918/1272] 18462.jpg: 0 objects detected
# 📸 [919/1272] 18463.jpg: 0 objects detected
# 📸 [920/1272] 18464.jpg: 0 objects detected
# 📸 [921/1272] 18465.jpg: 0 objects detected
# 📸 [922/1272] 18466.jpg: 1 objects detected
# 📸 [923/1272] 18467.jpg: 0 objects detected
# 📸 [924/1272] 18468.jpg: 0 objects detected
# 📸 [925/1272] 18469.jpg: 0 objects detected
# 📸 [926/1272] 18470.jpg: 0 objects detected
# 📸 [927/1272] 18471.jpg: 0 objects detected
# 📸 [928/1272] 18472.jpg: 0 objects detected
# 📸 [929/1272] 18473.jpg: 0 objects detected
# 📸 [930/1272] 18474.jpg: 1 objects detected
# 📸 [931/1272] 18475.jpg: 1 objects detected
# 📸 [932/1272] 18476.jpg: 1 objects detected
# 📸 [933/1272] 18477.jpg: 0 objects detected
# 📸 [934/1272] 18478.jpg: 1 objects detected
# 📸 [935/1272] 18479.jpg: 0 objects detected
# 📸 [936/1272] 18480.jpg: 0 objects detected
# 📸 [937/1272] 18481.jpg: 0 objects detected
# 📸 [938/1272] 18482.jpg: 0 objects detected
# 📸 [939/1272] 18483.jpg: 0 objects detected
# 📸 [940/1272] 18484.jpg: 0 objects detected
# 📸 [941/1272] 18485.jpg: 1 objects detected
# 📸 [942/1272] 18486.jpg: 1 objects detected
# 📸 [943/1272] 18487.jpg: 0 objects detected
# 📸 [944/1272] 18488.jpg: 1 objects detected
# 📸 [945/1272] 18489.jpg: 1 objects detected
# 📸 [946/1272] 18490.jpg: 0 objects detected
# 📸 [947/1272] 18491.jpg: 0 objects detected
# 📸 [948/1272] 18492.jpg: 0 objects detected
# 📸 [949/1272] 18493.jpg: 0 objects detected
# 📸 [950/1272] 18494.jpg: 0 objects detected
# 📸 [951/1272] 18495.jpg: 0 objects detected
# 📸 [952/1272] 18496.jpg: 0 objects detected
# 📸 [953/1272] 18497.jpg: 0 objects detected
# 📸 [954/1272] 18498.jpg: 1 objects detected
# 📸 [955/1272] 18499.jpg: 1 objects detected
# 📸 [956/1272] 18500.jpg: 0 objects detected
# 📸 [957/1272] 18501.jpg: 1 objects detected
# 📸 [958/1272] 18502.jpg: 1 objects detected
# 📸 [959/1272] 18503.jpg: 1 objects detected
# 📸 [960/1272] 18504.jpg: 1 objects detected
# 📸 [961/1272] 18505.jpg: 1 objects detected
# 📸 [962/1272] 18506.jpg: 1 objects detected
# 📸 [963/1272] 18507.jpg: 0 objects detected
# 📸 [964/1272] 18509.jpg: 1 objects detected
# 📸 [965/1272] 18510.jpg: 0 objects detected
# 📸 [966/1272] 18511.jpg: 0 objects detected
# 📸 [967/1272] 18512.jpg: 0 objects detected
# 📸 [968/1272] 18513.jpg: 0 objects detected
# 📸 [969/1272] 18514.jpg: 1 objects detected
# 📸 [970/1272] 18515.jpg: 0 objects detected
# 📸 [971/1272] 18516.jpg: 0 objects detected
# 📸 [972/1272] 18517.jpg: 0 objects detected
# 📸 [973/1272] 18518.jpg: 0 objects detected
# 📸 [974/1272] 18519.jpg: 0 objects detected
# 📸 [975/1272] 18520.jpg: 0 objects detected
# 📸 [976/1272] 18521.jpg: 1 objects detected
# 📸 [977/1272] 18522.jpg: 1 objects detected
# 📸 [978/1272] 18523.jpg: 0 objects detected
# 📸 [979/1272] 18524.jpg: 1 objects detected
# 📸 [980/1272] 18525.jpg: 0 objects detected
# 📸 [981/1272] 18526.jpg: 1 objects detected
# 📸 [982/1272] 18528.jpg: 0 objects detected
# 📸 [983/1272] 18529.jpg: 0 objects detected
# 📸 [984/1272] 18530.jpg: 0 objects detected
# 📸 [985/1272] 18531.jpg: 0 objects detected
# 📸 [986/1272] 18532.jpg: 1 objects detected
# 📸 [987/1272] 18533.jpg: 0 objects detected
# 📸 [988/1272] 18534.jpg: 0 objects detected
# 📸 [989/1272] 18535.jpg: 1 objects detected
# 📸 [990/1272] 18536.jpg: 0 objects detected
# 📸 [991/1272] 18537.jpg: 1 objects detected
# 📸 [992/1272] 18538.jpg: 0 objects detected
# 📸 [993/1272] 18539.jpg: 0 objects detected
# 📸 [994/1272] 18540.jpg: 0 objects detected
# 📸 [995/1272] 18541.jpg: 1 objects detected
# 📸 [996/1272] 18542.jpg: 0 objects detected
# 📸 [997/1272] 18543.jpg: 1 objects detected
# 📸 [998/1272] 18544.jpg: 0 objects detected
# 📸 [999/1272] 18545.jpg: 0 objects detected
# 📸 [1000/1272] 18546.jpg: 1 objects detected
# 📸 [1001/1272] 18547.jpg: 0 objects detected
# 📸 [1002/1272] 18548.jpg: 0 objects detected
# 📸 [1003/1272] 18549.jpg: 1 objects detected
# 📸 [1004/1272] 18550.jpg: 1 objects detected
# 📸 [1005/1272] 18551.jpg: 1 objects detected
# 📸 [1006/1272] 18552.jpg: 1 objects detected
# 📸 [1007/1272] 18553.jpg: 0 objects detected
# 📸 [1008/1272] 18554.jpg: 1 objects detected
# 📸 [1009/1272] 18555.jpg: 0 objects detected
# 📸 [1010/1272] 18556.jpg: 0 objects detected
# 📸 [1011/1272] 18557.jpg: 1 objects detected
# 📸 [1012/1272] 18558.jpg: 0 objects detected
# 📸 [1013/1272] 18559.jpg: 0 objects detected
# 📸 [1014/1272] 18560.jpg: 1 objects detected
# 📸 [1015/1272] 18561.jpg: 0 objects detected
# 📸 [1016/1272] 18562.jpg: 0 objects detected
# 📸 [1017/1272] 18563.jpg: 0 objects detected
# 📸 [1018/1272] 18564.jpg: 1 objects detected
# 📸 [1019/1272] 18565.jpg: 1 objects detected
# 📸 [1020/1272] 18566.jpg: 1 objects detected
# 📸 [1021/1272] 18567.jpg: 1 objects detected
# 📸 [1022/1272] 18568.jpg: 0 objects detected
# 📸 [1023/1272] 18569.jpg: 0 objects detected
# 📸 [1024/1272] 18570.jpg: 1 objects detected
# 📸 [1025/1272] 169658.jpg: 0 objects detected
# 📸 [1026/1272] 169667.jpg: 1 objects detected
# 📸 [1027/1272] 169670.jpg: 10 objects detected
# 📸 [1028/1272] 169685.jpg: 1 objects detected
# 📸 [1029/1272] 169700.jpg: 0 objects detected
# 📸 [1030/1272] 169707.jpg: 1 objects detected
# 📸 [1031/1272] 169712.jpg: 1 objects detected
# 📸 [1032/1272] 169721.jpg: 0 objects detected
# 📸 [1033/1272] 169722.jpg: 1 objects detected
# 📸 [1034/1272] 169733.jpg: 0 objects detected
# 📸 [1035/1272] 169737.jpg: 0 objects detected
# 📸 [1036/1272] 169756.jpg: 0 objects detected
# 📸 [1037/1272] 169757.jpg: 0 objects detected
# 📸 [1038/1272] 169763.jpg: 3 objects detected
# 📸 [1039/1272] 169764.jpg: 1 objects detected
# 📸 [1040/1272] 169772.jpg: 1 objects detected
# 📸 [1041/1272] 169797.jpg: 1 objects detected
# 📸 [1042/1272] 169819.jpg: 0 objects detected
# 📸 [1043/1272] 169820.jpg: 1 objects detected
# 📸 [1044/1272] 169837.jpg: 0 objects detected
# 📸 [1045/1272] 169864.jpg: 1 objects detected
# 📸 [1046/1272] 169867.jpg: 14 objects detected
# 📸 [1047/1272] 169887.jpg: 0 objects detected
# 📸 [1048/1272] 169927.jpg: 0 objects detected
# 📸 [1049/1272] 169938.jpg: 6 objects detected
# 📸 [1050/1272] 169957.jpg: 1 objects detected
# 📸 [1051/1272] 169989.jpg: 0 objects detected
# 📸 [1052/1272] 169999.jpg: 10 objects detected
# 📸 [1053/1272] 170035.jpg: 0 objects detected
# 📸 [1054/1272] 170041.jpg: 0 objects detected
# 📸 [1055/1272] 170056.jpg: 1 objects detected
# 📸 [1056/1272] 170084.jpg: 0 objects detected
# 📸 [1057/1272] 170098.jpg: 1 objects detected
# 📸 [1058/1272] 170118.jpg: 0 objects detected
# 📸 [1059/1272] 170128.jpg: 0 objects detected
# 📸 [1060/1272] 170142.jpg: 0 objects detected
# 📸 [1061/1272] 170168.jpg: 0 objects detected
# 📸 [1062/1272] 170173.jpg: 1 objects detected
# 📸 [1063/1272] 170195.jpg: 1 objects detected
# 📸 [1064/1272] 170202.jpg: 0 objects detected
# 📸 [1065/1272] 170270.jpg: 0 objects detected
# 📸 [1066/1272] 170272.jpg: 1 objects detected
# 📸 [1067/1272] 170276.jpg: 4 objects detected
# 📸 [1068/1272] 170278.jpg: 0 objects detected
# 📸 [1069/1272] 170310.jpg: 0 objects detected
# 📸 [1070/1272] 170314.jpg: 0 objects detected
# 📸 [1071/1272] 170315.jpg: 1 objects detected
# 📸 [1072/1272] 170326.jpg: 0 objects detected
# 📸 [1073/1272] 170343.jpg: 1 objects detected
# 📸 [1074/1272] 170351.jpg: 11 objects detected
# 📸 [1075/1272] 170378.jpg: 0 objects detected
# 📸 [1076/1272] 170401.jpg: 10 objects detected
# 📸 [1077/1272] 170434.jpg: 11 objects detected
# 📸 [1078/1272] 170452.jpg: 0 objects detected
# 📸 [1079/1272] 170455.jpg: 0 objects detected
# 📸 [1080/1272] 170476.jpg: 6 objects detected
# 📸 [1081/1272] 170495.jpg: 11 objects detected
# 📸 [1082/1272] 170503.jpg: 4 objects detected
# 📸 [1083/1272] 170512.jpg: 0 objects detected
# 📸 [1084/1272] 170531.jpg: 1 objects detected
# 📸 [1085/1272] 170544.jpg: 0 objects detected
# 📸 [1086/1272] 170559.jpg: 0 objects detected
# 📸 [1087/1272] 170570.jpg: 6 objects detected
# 📸 [1088/1272] 170571.jpg: 1 objects detected
# 📸 [1089/1272] 170605.jpg: 1 objects detected
# 📸 [1090/1272] 170606.jpg: 6 objects detected
# 📸 [1091/1272] 170622.jpg: 1 objects detected
# 📸 [1092/1272] 170642.jpg: 2 objects detected
# 📸 [1093/1272] 170664.jpg: 6 objects detected
# 📸 [1094/1272] 170680.jpg: 0 objects detected
# 📸 [1095/1272] 170681.jpg: 6 objects detected
# 📸 [1096/1272] 170688.jpg: 1 objects detected
# 📸 [1097/1272] 170705.jpg: 3 objects detected
# 📸 [1098/1272] 170724.jpg: 13 objects detected
# 📸 [1099/1272] 170730.jpg: 0 objects detected
# 📸 [1100/1272] 170736.jpg: 1 objects detected
# 📸 [1101/1272] 170738.jpg: 1 objects detected
# 📸 [1102/1272] 170741.jpg: 6 objects detected
# 📸 [1103/1272] 170756.jpg: 0 objects detected
# 📸 [1104/1272] 170757.jpg: 0 objects detected
# 📸 [1105/1272] 170768.jpg: 1 objects detected
# 📸 [1106/1272] 170776.jpg: 0 objects detected
# 📸 [1107/1272] 170826.jpg: 0 objects detected
# 📸 [1108/1272] 170847.jpg: 1 objects detected
# 📸 [1109/1272] 170850.jpg: 1 objects detected
# 📸 [1110/1272] 170855.jpg: 0 objects detected
# 📸 [1111/1272] 170856.jpg: 0 objects detected
# 📸 [1112/1272] 170857.jpg: 0 objects detected
# 📸 [1113/1272] 170889.jpg: 0 objects detected
# 📸 [1114/1272] 170923.jpg: 0 objects detected
# 📸 [1115/1272] 170937.jpg: 0 objects detected
# 📸 [1116/1272] 170938.jpg: 0 objects detected
# 📸 [1117/1272] 170962.jpg: 0 objects detected
# 📸 [1118/1272] 170966.jpg: 0 objects detected
# 📸 [1119/1272] 171006.jpg: 0 objects detected
# 📸 [1120/1272] 171009.jpg: 0 objects detected
# 📸 [1121/1272] 171012.jpg: 0 objects detected
# 📸 [1122/1272] 171016.jpg: 0 objects detected
# 📸 [1123/1272] 171049.jpg: 10 objects detected
# 📸 [1124/1272] 171113.jpg: 0 objects detected
# 📸 [1125/1272] 171136.jpg: 1 objects detected
# 📸 [1126/1272] 171138.jpg: 1 objects detected
# 📸 [1127/1272] 171172.jpg: 0 objects detected
# 📸 [1128/1272] 171173.jpg: 0 objects detected
# 📸 [1129/1272] 171193.jpg: 10 objects detected
# 📸 [1130/1272] 171199.jpg: 1 objects detected
# 📸 [1131/1272] 171206.jpg: 1 objects detected
# 📸 [1132/1272] 171226.jpg: 1 objects detected
# 📸 [1133/1272] 171229.jpg: 0 objects detected
# 📸 [1134/1272] 171263.jpg: 1 objects detected
# 📸 [1135/1272] 171264.jpg: 1 objects detected
# 📸 [1136/1272] 171277.jpg: 0 objects detected
# 📸 [1137/1272] 171305.jpg: 1 objects detected
# 📸 [1138/1272] 171319.jpg: 9 objects detected
# 📸 [1139/1272] 171324.jpg: 0 objects detected
# 📸 [1140/1272] 171371.jpg: 1 objects detected
# 📸 [1141/1272] 171375.jpg: 0 objects detected
# 📸 [1142/1272] 171379.jpg: 1 objects detected
# 📸 [1143/1272] 171387.jpg: 9 objects detected
# 📸 [1144/1272] 171412.jpg: 1 objects detected
# 📸 [1145/1272] 171414.jpg: 0 objects detected
# 📸 [1146/1272] 171420.jpg: 4 objects detected
# 📸 [1147/1272] 171421.jpg: 9 objects detected
# 📸 [1148/1272] 171448.jpg: 1 objects detected
# 📸 [1149/1272] 171453.jpg: 0 objects detected
# 📸 [1150/1272] 171461.jpg: 10 objects detected
# 📸 [1151/1272] 171464.jpg: 0 objects detected
# 📸 [1152/1272] 171472.jpg: 0 objects detected
# 📸 [1153/1272] 171473.jpg: 0 objects detected
# 📸 [1154/1272] 171529.jpg: 10 objects detected
# 📸 [1155/1272] 171535.jpg: 0 objects detected
# 📸 [1156/1272] 171572.jpg: 0 objects detected
# 📸 [1157/1272] 171612.jpg: 0 objects detected
# 📸 [1158/1272] 171613.jpg: 0 objects detected
# 📸 [1159/1272] 171622.jpg: 1 objects detected
# 📸 [1160/1272] 171633.jpg: 0 objects detected
# 📸 [1161/1272] 171681.jpg: 1 objects detected
# 📸 [1162/1272] 171686.jpg: 0 objects detected
# 📸 [1163/1272] 171687.jpg: 0 objects detected
# 📸 [1164/1272] 171692.jpg: 1 objects detected
# 📸 [1165/1272] 171717.jpg: 1 objects detected
# 📸 [1166/1272] 171722.jpg: 1 objects detected
# 📸 [1167/1272] 171724.jpg: 0 objects detected
# 📸 [1168/1272] 171728.jpg: 0 objects detected
# 📸 [1169/1272] 171732.jpg: 1 objects detected
# 📸 [1170/1272] 171734.jpg: 0 objects detected
# 📸 [1171/1272] 171746.jpg: 0 objects detected
# 📸 [1172/1272] 171752.jpg: 0 objects detected
# 📸 [1173/1272] 171756.jpg: 0 objects detected
# 📸 [1174/1272] 171758.jpg: 0 objects detected
# 📸 [1175/1272] 171761.jpg: 0 objects detected
# 📸 [1176/1272] 171764.jpg: 5 objects detected
# 📸 [1177/1272] 171770.jpg: 1 objects detected
# 📸 [1178/1272] 171772.jpg: 0 objects detected
# 📸 [1179/1272] 171773.jpg: 0 objects detected
# 📸 [1180/1272] 171779.jpg: 0 objects detected
# 📸 [1181/1272] 171785.jpg: 2 objects detected
# 📸 [1182/1272] 171787.jpg: 0 objects detected
# 📸 [1183/1272] 171792.jpg: 1 objects detected
# 📸 [1184/1272] 171794.jpg: 0 objects detected
# 📸 [1185/1272] 171799.jpg: 0 objects detected
# 📸 [1186/1272] 171804.jpg: 0 objects detected
# 📸 [1187/1272] 171812.jpg: 0 objects detected
# 📸 [1188/1272] 171815.jpg: 0 objects detected
# 📸 [1189/1272] 171821.jpg: 0 objects detected
# 📸 [1190/1272] 171822.jpg: 1 objects detected
# 📸 [1191/1272] 171834.jpg: 0 objects detected
# 📸 [1192/1272] 171836.jpg: 1 objects detected
# 📸 [1193/1272] 171838.jpg: 4 objects detected
# 📸 [1194/1272] 171839.jpg: 0 objects detected
# 📸 [1195/1272] 171846.jpg: 0 objects detected
# 📸 [1196/1272] 171851.jpg: 0 objects detected
# 📸 [1197/1272] 171857.jpg: 0 objects detected
# 📸 [1198/1272] 171862.jpg: 0 objects detected
# 📸 [1199/1272] 171863.jpg: 2 objects detected
# 📸 [1200/1272] 171864.jpg: 0 objects detected
# 📸 [1201/1272] 171867.jpg: 0 objects detected
# 📸 [1202/1272] 171869.jpg: 0 objects detected
# 📸 [1203/1272] 171871.jpg: 0 objects detected
# 📸 [1204/1272] 171875.jpg: 1 objects detected
# 📸 [1205/1272] 171876.jpg: 0 objects detected
# 📸 [1206/1272] 171886.jpg: 0 objects detected
# 📸 [1207/1272] 171888.jpg: 4 objects detected
# 📸 [1208/1272] 171893.jpg: 0 objects detected
# 📸 [1209/1272] 171900.jpg: 1 objects detected
# 📸 [1210/1272] 171902.jpg: 1 objects detected
# 📸 [1211/1272] 171904.jpg: 1 objects detected
# 📸 [1212/1272] 171906.jpg: 0 objects detected
# 📸 [1213/1272] 171907.jpg: 1 objects detected
# 📸 [1214/1272] 171913.jpg: 1 objects detected
# 📸 [1215/1272] 171914.jpg: 0 objects detected
# 📸 [1216/1272] 171920.jpg: 2 objects detected
# 📸 [1217/1272] 171935.jpg: 1 objects detected
# 📸 [1218/1272] 171937.jpg: 0 objects detected
# 📸 [1219/1272] 171938.jpg: 1 objects detected
# 📸 [1220/1272] 171944.jpg: 4 objects detected
# 📸 [1221/1272] 171950.jpg: 1 objects detected
# 📸 [1222/1272] 171960.jpg: 0 objects detected
# 📸 [1223/1272] 171980.jpg: 1 objects detected
# 📸 [1224/1272] 171985.jpg: 0 objects detected
# 📸 [1225/1272] 171989.jpg: 1 objects detected
# 📸 [1226/1272] 171999.jpg: 0 objects detected
# 📸 [1227/1272] 172000.jpg: 0 objects detected
# 📸 [1228/1272] 172014.jpg: 1 objects detected
# 📸 [1229/1272] 172020.jpg: 1 objects detected
# 📸 [1230/1272] 172028.jpg: 9 objects detected
# 📸 [1231/1272] 172038.jpg: 1 objects detected
# 📸 [1232/1272] 172044.jpg: 1 objects detected
# 📸 [1233/1272] 172057.jpg: 1 objects detected
# 📸 [1234/1272] 172059.jpg: 1 objects detected
# 📸 [1235/1272] 172061.jpg: 0 objects detected
# 📸 [1236/1272] 172067.jpg: 0 objects detected
# 📸 [1237/1272] 172071.jpg: 0 objects detected
# 📸 [1238/1272] 172077.jpg: 4 objects detected
# 📸 [1239/1272] 172092.jpg: 1 objects detected
# 📸 [1240/1272] 172093.jpg: 0 objects detected
# 📸 [1241/1272] 172095.jpg: 0 objects detected
# 📸 [1242/1272] 172099.jpg: 1 objects detected
# 📸 [1243/1272] 172109.jpg: 0 objects detected
# 📸 [1244/1272] 172114.jpg: 0 objects detected
# 📸 [1245/1272] 172122.jpg: 0 objects detected
# 📸 [1246/1272] 172123.jpg: 0 objects detected
# 📸 [1247/1272] 172135.jpg: 2 objects detected
# 📸 [1248/1272] 172172.jpg: 0 objects detected
# 📸 [1249/1272] 172178.jpg: 1 objects detected
# 📸 [1250/1272] 172185.jpg: 0 objects detected
# 📸 [1251/1272] 172186.jpg: 0 objects detected
# 📸 [1252/1272] 172252.jpg: 0 objects detected
# 📸 [1253/1272] 172263.jpg: 1 objects detected
# 📸 [1254/1272] 172272.jpg: 0 objects detected
# 📸 [1255/1272] 172307.jpg: 8 objects detected
# 📸 [1256/1272] 172345.jpg: 0 objects detected
# 📸 [1257/1272] 172350.jpg: 0 objects detected
# 📸 [1258/1272] 172367.jpg: 1 objects detected
# 📸 [1259/1272] 172422.jpg: 0 objects detected
# 📸 [1260/1272] 172431.jpg: 6 objects detected
# 📸 [1261/1272] 172448.jpg: 10 objects detected
# 📸 [1262/1272] 172451.jpg: 1 objects detected
# 📸 [1263/1272] 172488.jpg: 0 objects detected
# 📸 [1264/1272] 172510.jpg: 0 objects detected
# 📸 [1265/1272] 172525.jpg: 1 objects detected
# 📸 [1266/1272] 172530.jpg: 0 objects detected
# 📸 [1267/1272] 172531.jpg: 10 objects detected
# 📸 [1268/1272] 172546.jpg: 0 objects detected
# 📸 [1269/1272] 172566.jpg: 1 objects detected
# 📸 [1270/1272] 172604.jpg: 0 objects detected
# 📸 [1271/1272] 172631.jpg: 1 objects detected
# 📸 [1272/1272] 172644.jpg: 0 objects detected
#
# ✅ Processing complete!
# 📊 Successfully processed: 1272 images
# ❌ Errors: 0 images

# %% [markdown]
# ## Save Detection Results to PostgreSQL
# Store the detection results in the database.

# %%
if processed_data:
    try:
        print("💾 Saving results to PostgreSQL...")
        loader.load_processed_images(processed_data)
        print(f"✅ Successfully saved {len(processed_data)} detection results to database")
    except Exception as e:
        print(f"❌ Error saving to database: {e}")
else:
    print("⚠️ No data to save - no images were processed successfully")

# Close database connection
loader.disconnect()
print("🔌 Database connection closed")
# Out:
# 💾 Saving results to PostgreSQL...
# Inserted/updated 1272 processed images
# ✅ Successfully saved 1272 detection results to database
# 🔌 Database connection closed

# %% [markdown]
# ## Summary and Analysis
# Let's analyze the detection results.

# %%
if processed_data:
    # Analyze results
    total_detections = sum(len(item['detection_results']) for item in processed_data)
    avg_detections = total_detections / len(processed_data) if processed_data else 0
    
    # Count object classes
    class_counts = {}
    for item in processed_data:
        for detection in item['detection_results']:
            class_name = detection.get('class_name', 'unknown')
            class_counts[class_name] = class_counts.get(class_name, 0) + 1
    
    print("📈 Detection Summary:")
    print(f"   • Images processed: {len(processed_data)}")
    print(f"   • Total objects detected: {total_detections}")
    print(f"   • Average objects per image: {avg_detections:.2f}")
    
    if class_counts:
        print(f"\n🏷️ Top detected objects:")
        sorted_classes = sorted(class_counts.items(), key=lambda x: x[1], reverse=True)
        for class_name, count in sorted_classes[:10]:
            print(f"   • {class_name}: {count}")

if errors:
    print(f"\n❌ Errors encountered ({len(errors)}):")
    for error in errors[:5]:  # Show first 5 errors
        print(f"   • {error}")
    if len(errors) > 5:
        print(f"   ... and {len(errors) - 5} more errors")

print("\n🎉 Processing pipeline complete!")
# Out:
# 📈 Detection Summary:
#    • Images processed: 1272
#    • Total objects detected: 730
#    • Average objects per image: 0.57
#
# 🏷️ Top detected objects:
#    • person: 281
#    • bottle: 280
#    • cup: 29
#    • tv: 19
#    • refrigerator: 16
#    • cell phone: 15
#    • scissors: 11
#    • chair: 11
#    • vase: 11
#    • book: 8
#
# 🎉 Processing pipeline complete!

# %% [markdown]
# ## Verify Database Results
# Let's check that the data was saved correctly in the database.

# %%
# Reconnect to database for verification
loader = PostgresLoader()
loader.connect()

try:
    # Query recent processed images
    cursor = loader.conn.cursor()
    cursor.execute("""
        SELECT message_id, image_path, 
               jsonb_array_length(detection_results) as detection_count,
               processed_at
        FROM processed_images 
        WHERE processed_at >= CURRENT_DATE
        ORDER BY processed_at DESC 
        LIMIT 10
    """)
    
    results = cursor.fetchall()
    
    if results:
        print("📊 Recent database entries:")
        for row in results:
            print(f"   • Message {row[0]}: {row[2]} detections ({row[1]})")
    else:
        print("📊 No recent entries found in database")
        
except Exception as e:
    print(f"❌ Error querying database: {e}")
finally:
    cursor.close()
    loader.disconnect()
# Out:
# Connected to PostgreSQL successfully
# 📊 Recent database entries:
#    • Message 11: 0 detections (data\raw\telegram_images\2025-07-14\CheMed123\11.jpg)
#    • Message 13: 1 detections (data\raw\telegram_images\2025-07-14\CheMed123\13.jpg)
#    • Message 14: 0 detections (data\raw\telegram_images\2025-07-14\CheMed123\14.jpg)
#    • Message 15: 0 detections (data\raw\telegram_images\2025-07-14\CheMed123\15.jpg)
#    • Message 17: 1 detections (data\raw\telegram_images\2025-07-14\CheMed123\17.jpg)
#    • Message 18: 0 detections (data\raw\telegram_images\2025-07-14\CheMed123\18.jpg)
#    • Message 19: 2 detections (data\raw\telegram_images\2025-07-14\CheMed123\19.jpg)
#    • Message 2: 0 detections (data\raw\telegram_images\2025-07-14\CheMed123\2.jpg)
#    • Message 20: 2 detections (data\raw\telegram_images\2025-07-14\CheMed123\20.jpg)
#    • Message 10: 0 detections (data\raw\telegram_images\2025-07-14\CheMed123\10.jpg)
