# %% [markdown]
# # Dagster Pipeline for Telegram Medical Data
#
# This notebook demonstrates how to use the Dagster pipeline for processing Telegram medical data.
#
# ## Overview
# The pipeline consists of the following operations:
# 1. **scrape_telegram_data**: Scrapes data from Telegram channels using Telethon
# 2. **load_raw_to_postgres**: Loads raw data to PostgreSQL
# 3. **run_dbt_transformations**: Runs dbt transformations
# 4. **run_yolo_enrichment**: Processes images with YOLO
# 5. **generate_pipeline_report**: Creates execution reports
#
# ## Setup
# Make sure you have:
# - All dependencies installed in your environment
# - Environment variables configured (.env file)
# - PostgreSQL database running

# %% [markdown]
# Imports and Setup

# %%
# Import required libraries
import sys
import os
from pathlib import Path

# Add project root to Python path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# Import Dagster components
from dagster import (
    execute_job, 
    DagsterInstance, 
    get_dagster_logger,
    job, 
    op
)

# Import pipeline components
from dags.telegram_pipeline import (
    telegram_pipeline_job,
    scrape_telegram_data,
    load_raw_to_postgres,
    run_dbt_transformations,
    run_yolo_enrichment,
    generate_pipeline_report
)

# Import source modules
from src.scraper.telegram_scraper import TelegramScraper
from src.loader.postgres_loader import PostgresLoader
from src.enrich.yolo_enricher import YOLOEnricher
from src.dbt_runner.dbt_executor import DBTExecutor
from src.utils.config import get_config

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## Environment Check
#
# Let's verify that our environment is properly configured and all components are working.

# %%
# Check environment variables
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Required environment variables
required_vars = [
    'TELEGRAM_API_ID',
    'TELEGRAM_API_HASH', 
    'TELEGRAM_PHONE'
]

print("🔍 Checking Environment Variables:")
print("=" * 50)

missing_vars = []
for var in required_vars:
    value = os.getenv(var)
    if value:
        # Mask sensitive values
        if 'API' in var or 'HASH' in var or 'PASSWORD' in var:
            display_value = value[:4] + "..." + value[-4:] if len(value) > 8 else "***"
        else:
            display_value = value
        print(f"✅ {var}: {display_value}")
    else:
        print(f"❌ {var}: NOT SET")
        missing_vars.append(var)

if missing_vars:
    print(f"\n⚠️  Missing environment variables: {missing_vars}")
    print("Please set these in your .env file")
else:
    print("\n✅ All required environment variables are set!")

# Check Dagster instance
try:
    instance = DagsterInstance.ephemeral()
    print("✅ Dagster instance created successfully")
except Exception as e:
    print(f"❌ Dagster instance error: {e}")
# Out:
# 🔍 Checking Environment Variables:
# ==================================================
# ✅ TELEGRAM_API_ID: ***
# ✅ TELEGRAM_API_HASH: 041e...b3e7
# ✅ TELEGRAM_PHONE: +251715349456
#
# ✅ All required environment variables are set!
# 2025-07-16 03:51:33,063 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:51:33,064 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:51:33,147 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:51:33,158 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:51:33,160 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:51:33,226 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# ✅ Dagster instance created successfully

# %% [markdown]
# ## Pipeline Components Overview
#
# Let's examine the individual operations that make up our pipeline.

# %%
# Display pipeline structure
print("📋 Pipeline Components:")
print("=" * 50)

components = [
    ("scrape_telegram_data", "Scrapes Telegram channels for medical data"),
    ("load_raw_to_postgres", "Loads raw data to PostgreSQL database"),
    ("run_dbt_transformations", "Runs dbt models and transformations"),
    ("run_yolo_enrichment", "Processes images with YOLO for medical content"),
    ("generate_pipeline_report", "Creates comprehensive execution report")
]

for i, (name, description) in enumerate(components, 1):
    print(f"{i}. {name}")
    print(f"   └─ {description}")

print(f"\n�� Main Job: telegram_pipeline_job")
print("   └─ Orchestrates all operations in sequence")

# Show job definition
print(f"\n�� Job Definition:")
print(f"   {telegram_pipeline_job.__doc__}")
# Out:
# 📋 Pipeline Components:
# ==================================================
# 1. scrape_telegram_data
#    └─ Scrapes Telegram channels for medical data
# 2. load_raw_to_postgres
#    └─ Loads raw data to PostgreSQL database
# 3. run_dbt_transformations
#    └─ Runs dbt models and transformations
# 4. run_yolo_enrichment
#    └─ Processes images with YOLO for medical content
# 5. generate_pipeline_report
#    └─ Creates comprehensive execution report
#
# �� Main Job: telegram_pipeline_job
#    └─ Orchestrates all operations in sequence
#
# �� Job Definition:
#
#     Main Dagster job for the Telegram medical data pipeline.
#
#     This job orchestrates the following operations:
#     1. scrape_telegram_data: Scrapes data from Telegram channels
#     2. load_raw_to_postgres: Loads raw data to PostgreSQL
#     3. run_dbt_transformations: Runs dbt transformations
#     4. run_yolo_enrichment: Processes images with YOLO
#     5. generate_pipeline_report: Generates execution report

# %% [markdown]
# ## Individual Operation Testing
#
# Let's test each operation individually to ensure they work correctly.

# %% [markdown]
# Test Scraping Operation

# %%
# Test scraping operation
print("🧪 Testing Scraping Operation")
print("=" * 50)

try:
    # Create a test context
    from dagster import build_op_context
    
    context = build_op_context()
    
    # Test the scraping operation
    result = scrape_telegram_data(context)
    
    print(f"✅ Scraping operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Messages scraped: {result.get('message_count', 0)}")
    print(f"Channels processed: {result.get('channels_processed', 0)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ Scraping test failed: {e}")
    print("This might be due to:")
    print("- Missing Telegram credentials")
    print("- Network connectivity issues")
    print("- Rate limiting from Telegram")
# Out:
# 🧪 Testing Scraping Operation
# ==================================================
# 2025-07-16 03:51:33,318 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:51:33,318 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:51:33,402 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:51:33,414 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:51:33,414 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:51:33,500 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:51:33,506 - dagster.builtin - INFO - Starting Telegram data scraping operation
# 2025-07-16 03:51:33,508 - src.scraper.telegram_scraper - INFO - Initialized TelegramScraper with 3 target channels
# 2025-07-16 03:51:33,511 - telethon.network.mtprotosender - INFO - Connecting to 149.154.167.91:443/TcpFull...
# 2025-07-16 03:51:33,673 - telethon.network.mtprotosender - INFO - Connection to 149.154.167.91:443/TcpFull complete!
# 2025-07-16 03:51:34,436 - src.scraper.telegram_scraper - INFO - Successfully connected to Telegram
# 2025-07-16 03:51:34,440 - dagster.builtin - INFO - Successfully connected to Telegram
# 2025-07-16 03:51:34,442 - src.scraper.telegram_scraper - INFO - Starting scrape for 3 channels
# 2025-07-16 03:51:34,442 - src.scraper.telegram_scraper - INFO - Starting scrape for channel: CheMed123
# 2025-07-16 03:51:34,442 - src.scraper.telegram_scraper - INFO - Starting to scrape channel: CheMed123
# 2025-07-16 03:51:35,071 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:35,662 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\97.jpg
# 2025-07-16 03:51:35,669 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:36,598 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\96.jpg
# 2025-07-16 03:51:36,598 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:37,259 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\95.jpg
# 2025-07-16 03:51:37,275 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:37,953 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\94.jpg
# 2025-07-16 03:51:37,959 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:39,073 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\93.jpg
# 2025-07-16 03:51:39,077 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:40,079 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\92.jpg
# 2025-07-16 03:51:40,079 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:40,597 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\91.jpg
# 2025-07-16 03:51:40,601 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:42,128 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\90.jpg
# 2025-07-16 03:51:42,128 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:43,214 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\88.jpg
# 2025-07-16 03:51:43,253 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:44,341 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\87.jpg
# 2025-07-16 03:51:44,341 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:45,480 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\86.jpg
# 2025-07-16 03:51:45,491 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:46,230 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\85.jpg
# 2025-07-16 03:51:46,230 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:46,954 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\82.jpg
# 2025-07-16 03:51:46,961 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:48,356 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\81.jpg
# 2025-07-16 03:51:48,358 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:49,335 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\80.jpg
# 2025-07-16 03:51:49,341 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:50,678 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\79.jpg
# 2025-07-16 03:51:50,690 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:52,464 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\77.jpg
# 2025-07-16 03:51:52,474 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:54,152 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\76.jpg
# 2025-07-16 03:51:54,156 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:56,437 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\75.jpg
# 2025-07-16 03:51:56,445 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:57,974 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\71.jpg
# 2025-07-16 03:51:57,982 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:51:59,481 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\70.jpg
# 2025-07-16 03:51:59,485 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:02,497 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\67.jpg
# 2025-07-16 03:52:02,504 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:05,479 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\64.jpg
# 2025-07-16 03:52:05,487 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:07,382 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\60.jpg
# 2025-07-16 03:52:07,390 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:09,493 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\59.jpg
# 2025-07-16 03:52:09,500 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:10,590 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\58.jpg
# 2025-07-16 03:52:10,599 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:13,279 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\55.jpg
# 2025-07-16 03:52:13,287 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:15,110 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\52.jpg
# 2025-07-16 03:52:15,118 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:16,900 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\50.jpg
# 2025-07-16 03:52:16,907 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:18,673 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\49.jpg
# 2025-07-16 03:52:18,679 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:22,483 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\48.jpg
# 2025-07-16 03:52:22,490 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:24,472 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\46.jpg
# 2025-07-16 03:52:24,480 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:26,640 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\45.jpg
# 2025-07-16 03:52:26,649 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:28,921 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\43.jpg
# 2025-07-16 03:52:28,930 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:31,860 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\41.jpg
# 2025-07-16 03:52:31,868 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:33,784 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\40.jpg
# 2025-07-16 03:52:33,793 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:35,831 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\39.jpg
# 2025-07-16 03:52:35,838 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:37,747 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\38.jpg
# 2025-07-16 03:52:37,754 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:39,508 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\34.jpg
# 2025-07-16 03:52:39,518 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:42,483 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\33.jpg
# 2025-07-16 03:52:42,492 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:44,748 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\31.jpg
# 2025-07-16 03:52:44,760 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:46,118 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\30.jpg
# 2025-07-16 03:52:46,128 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:47,790 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\27.jpg
# 2025-07-16 03:52:47,798 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:51,117 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\26.jpg
# 2025-07-16 03:52:51,126 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:52,974 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\25.jpg
# 2025-07-16 03:52:52,981 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:54,686 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\23.jpg
# 2025-07-16 03:52:54,696 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:56,047 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\22.jpg
# 2025-07-16 03:52:56,055 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:52:58,121 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\21.jpg
# 2025-07-16 03:52:58,129 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:02,584 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\20.jpg
# 2025-07-16 03:53:02,592 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:07,096 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\19.jpg
# 2025-07-16 03:53:07,104 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:09,108 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\18.jpg
# 2025-07-16 03:53:09,115 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:11,286 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\17.jpg
# 2025-07-16 03:53:11,295 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:12,957 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\15.jpg
# 2025-07-16 03:53:12,966 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:15,460 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\14.jpg
# 2025-07-16 03:53:15,469 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:19,267 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\13.jpg
# 2025-07-16 03:53:19,276 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:21,418 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\11.jpg
# 2025-07-16 03:53:21,426 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:23,982 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\10.jpg
# 2025-07-16 03:53:23,992 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:24,926 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\9.jpg
# 2025-07-16 03:53:24,932 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:25,964 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\2.jpg
# 2025-07-16 03:53:25,968 - src.scraper.telegram_scraper - INFO - Successfully scraped 63 messages from CheMed123
# 2025-07-16 03:53:25,983 - src.scraper.telegram_scraper - INFO - Saved 63 messages to data/raw/telegram_messages\2025-07-16\CheMed123\CheMed123.json
# 2025-07-16 03:53:25,986 - src.scraper.telegram_scraper - INFO - Completed scraping CheMed123: 63 messages in 111.53s
# 2025-07-16 03:53:28,005 - src.scraper.telegram_scraper - INFO - Starting scrape for channel: lobelia4cosmetics
# 2025-07-16 03:53:28,010 - src.scraper.telegram_scraper - INFO - Starting to scrape channel: lobelia4cosmetics
# 2025-07-16 03:53:28,999 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:30,352 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18584.jpg
# 2025-07-16 03:53:30,364 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:32,431 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18583.jpg
# 2025-07-16 03:53:32,440 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:34,347 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18582.jpg
# 2025-07-16 03:53:34,356 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:34,927 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18581.jpg
# 2025-07-16 03:53:34,935 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:36,470 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18580.jpg
# 2025-07-16 03:53:36,479 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:37,206 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18579.jpg
# 2025-07-16 03:53:37,214 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:40,090 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18578.jpg
# 2025-07-16 03:53:40,098 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:41,410 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18577.jpg
# 2025-07-16 03:53:41,417 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:43,489 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18575.jpg
# 2025-07-16 03:53:43,497 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:44,688 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18574.jpg
# 2025-07-16 03:53:44,696 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:45,832 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18573.jpg
# 2025-07-16 03:53:45,841 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:46,520 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18572.jpg
# 2025-07-16 03:53:46,529 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:48,282 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18571.jpg
# 2025-07-16 03:53:48,290 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:49,035 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18570.jpg
# 2025-07-16 03:53:49,043 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:50,778 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18569.jpg
# 2025-07-16 03:53:50,789 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:52,598 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18568.jpg
# 2025-07-16 03:53:52,608 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:54,671 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18567.jpg
# 2025-07-16 03:53:54,680 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:56,975 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18566.jpg
# 2025-07-16 03:53:56,982 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:58,472 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18565.jpg
# 2025-07-16 03:53:58,480 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:53:59,512 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18564.jpg
# 2025-07-16 03:53:59,517 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:02,089 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18563.jpg
# 2025-07-16 03:54:02,102 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:02,737 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18562.jpg
# 2025-07-16 03:54:02,746 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:03,531 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18561.jpg
# 2025-07-16 03:54:03,536 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:04,283 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18560.jpg
# 2025-07-16 03:54:04,286 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:04,709 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18559.jpg
# 2025-07-16 03:54:04,713 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:05,069 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18558.jpg
# 2025-07-16 03:54:05,075 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:06,353 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18557.jpg
# 2025-07-16 03:54:06,359 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:08,917 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18556.jpg
# 2025-07-16 03:54:08,920 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:11,135 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18555.jpg
# 2025-07-16 03:54:11,142 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:12,259 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18554.jpg
# 2025-07-16 03:54:12,264 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:14,907 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18553.jpg
# 2025-07-16 03:54:14,915 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:15,626 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18552.jpg
# 2025-07-16 03:54:15,631 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:16,553 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18551.jpg
# 2025-07-16 03:54:16,560 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:17,804 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18550.jpg
# 2025-07-16 03:54:17,809 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:19,084 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18549.jpg
# 2025-07-16 03:54:19,089 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:20,080 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18548.jpg
# 2025-07-16 03:54:20,084 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:20,372 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18547.jpg
# 2025-07-16 03:54:20,376 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:21,282 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18546.jpg
# 2025-07-16 03:54:21,287 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:22,112 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18545.jpg
# 2025-07-16 03:54:22,116 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:22,560 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18544.jpg
# 2025-07-16 03:54:22,565 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:22,818 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18543.jpg
# 2025-07-16 03:54:22,822 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:23,125 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18542.jpg
# 2025-07-16 03:54:23,129 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:23,444 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18541.jpg
# 2025-07-16 03:54:23,448 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:24,114 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18540.jpg
# 2025-07-16 03:54:24,120 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:24,580 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18539.jpg
# 2025-07-16 03:54:24,585 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:25,716 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18538.jpg
# 2025-07-16 03:54:25,723 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:26,783 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18537.jpg
# 2025-07-16 03:54:26,788 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:27,284 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18536.jpg
# 2025-07-16 03:54:27,292 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:28,726 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18535.jpg
# 2025-07-16 03:54:28,733 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:30,370 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18534.jpg
# 2025-07-16 03:54:30,376 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:31,143 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18533.jpg
# 2025-07-16 03:54:31,150 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:33,054 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18532.jpg
# 2025-07-16 03:54:33,062 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:33,680 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18531.jpg
# 2025-07-16 03:54:33,687 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:35,090 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18530.jpg
# 2025-07-16 03:54:35,095 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:35,518 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18529.jpg
# 2025-07-16 03:54:35,523 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:35,805 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18528.jpg
# 2025-07-16 03:54:35,812 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:37,248 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18526.jpg
# 2025-07-16 03:54:37,255 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:38,141 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18525.jpg
# 2025-07-16 03:54:38,146 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:39,884 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18524.jpg
# 2025-07-16 03:54:39,890 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:40,230 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18522.jpg
# 2025-07-16 03:54:40,236 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:41,040 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18521.jpg
# 2025-07-16 03:54:41,047 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:42,917 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18520.jpg
# 2025-07-16 03:54:42,923 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:46,106 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18519.jpg
# 2025-07-16 03:54:46,113 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:46,960 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18518.jpg
# 2025-07-16 03:54:46,966 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:47,268 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18517.jpg
# 2025-07-16 03:54:47,275 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:47,607 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18516.jpg
# 2025-07-16 03:54:47,612 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:49,151 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18515.jpg
# 2025-07-16 03:54:49,159 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:49,694 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18514.jpg
# 2025-07-16 03:54:49,699 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:50,128 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18513.jpg
# 2025-07-16 03:54:50,134 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:50,581 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18512.jpg
# 2025-07-16 03:54:50,588 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:51,215 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18511.jpg
# 2025-07-16 03:54:51,222 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:52,062 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18510.jpg
# 2025-07-16 03:54:52,067 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:52,728 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18509.jpg
# 2025-07-16 03:54:52,733 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:53,064 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18507.jpg
# 2025-07-16 03:54:53,069 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:54,636 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18506.jpg
# 2025-07-16 03:54:54,643 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:56,240 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18505.jpg
# 2025-07-16 03:54:56,247 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:57,582 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18504.jpg
# 2025-07-16 03:54:57,586 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:54:59,053 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18503.jpg
# 2025-07-16 03:54:59,058 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:00,559 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18502.jpg
# 2025-07-16 03:55:00,565 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:02,156 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18501.jpg
# 2025-07-16 03:55:02,161 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:02,796 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18500.jpg
# 2025-07-16 03:55:02,802 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:04,896 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18499.jpg
# 2025-07-16 03:55:04,901 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:06,295 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18498.jpg
# 2025-07-16 03:55:06,299 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:06,779 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18497.jpg
# 2025-07-16 03:55:06,783 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:07,911 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18496.jpg
# 2025-07-16 03:55:07,918 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:09,192 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18495.jpg
# 2025-07-16 03:55:09,199 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:10,007 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18494.jpg
# 2025-07-16 03:55:10,013 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:10,728 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18493.jpg
# 2025-07-16 03:55:10,733 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:11,371 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18492.jpg
# 2025-07-16 03:55:11,380 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:14,177 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18491.jpg
# 2025-07-16 03:55:14,181 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:17,204 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18490.jpg
# 2025-07-16 03:55:17,210 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:17,751 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18489.jpg
# 2025-07-16 03:55:17,757 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:19,883 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18488.jpg
# 2025-07-16 03:55:19,891 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:20,578 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18487.jpg
# 2025-07-16 03:55:20,585 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:22,594 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18486.jpg
# 2025-07-16 03:55:22,600 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:24,787 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18485.jpg
# 2025-07-16 03:55:24,796 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:26,126 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18484.jpg
# 2025-07-16 03:55:26,136 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:29,993 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18483.jpg
# 2025-07-16 03:55:31,332 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:33,090 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18482.jpg
# 2025-07-16 03:55:33,101 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:36,409 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18481.jpg
# 2025-07-16 03:55:36,415 - src.scraper.telegram_scraper - INFO - Scraped 100 messages from lobelia4cosmetics
# 2025-07-16 03:55:36,422 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:40,060 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18480.jpg
# 2025-07-16 03:55:40,067 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:40,733 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18479.jpg
# 2025-07-16 03:55:40,741 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:42,710 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18478.jpg
# 2025-07-16 03:55:42,717 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:44,139 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18477.jpg
# 2025-07-16 03:55:44,145 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:46,678 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18476.jpg
# 2025-07-16 03:55:46,683 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:47,620 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18475.jpg
# 2025-07-16 03:55:47,626 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:48,804 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18474.jpg
# 2025-07-16 03:55:48,809 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:55:49,340 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18473.jpg
# ...
# 2025-07-16 04:10:24,791 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170531.jpg
# 2025-07-16 04:10:24,796 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:25,755 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170512.jpg
# 2025-07-16 04:10:25,760 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:27,370 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170503.jpg
# 2025-07-16 04:10:27,375 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:28,789 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170495.jpg
# 2025-07-16 04:10:28,795 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:29,549 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170476.jpg
# 2025-07-16 04:10:29,557 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:29,790 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170455.jpg
# 2025-07-16 04:10:29,795 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:32,472 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170452.jpg
# 2025-07-16 04:10:32,477 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:33,963 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170434.jpg
# 2025-07-16 04:10:33,975 - src.scraper.telegram_scraper - INFO - Scraped 800 messages from tikvahpharma
# 2025-07-16 04:10:33,980 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:36,686 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170401.jpg
# 2025-07-16 04:10:36,692 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:37,085 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170378.jpg
# 2025-07-16 04:10:37,089 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:38,431 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170351.jpg
# 2025-07-16 04:10:38,434 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:40,205 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170343.jpg
# 2025-07-16 04:10:40,209 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:40,393 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170326.jpg
# 2025-07-16 04:10:40,399 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:42,204 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170315.jpg
# 2025-07-16 04:10:42,207 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:42,399 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170314.jpg
# 2025-07-16 04:10:42,403 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:42,620 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170310.jpg
# 2025-07-16 04:10:42,624 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:42,803 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170278.jpg
# 2025-07-16 04:10:42,807 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:43,912 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170276.jpg
# 2025-07-16 04:10:43,916 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:46,149 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170272.jpg
# 2025-07-16 04:10:46,154 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:47,905 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170270.jpg
# 2025-07-16 04:10:47,912 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:48,297 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170202.jpg
# 2025-07-16 04:10:48,301 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:50,518 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170195.jpg
# 2025-07-16 04:10:50,521 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:52,227 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170173.jpg
# 2025-07-16 04:10:52,231 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:52,750 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170168.jpg
# 2025-07-16 04:10:52,754 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:53,128 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170142.jpg
# 2025-07-16 04:10:53,677 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:54,654 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170128.jpg
# 2025-07-16 04:10:54,659 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:55,864 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170118.jpg
# 2025-07-16 04:10:55,867 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:57,813 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170098.jpg
# 2025-07-16 04:10:57,820 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:58,312 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170084.jpg
# 2025-07-16 04:10:58,318 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:10:59,629 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170056.jpg
# 2025-07-16 04:10:59,635 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:00,534 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170041.jpg
# 2025-07-16 04:11:00,537 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:01,857 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170035.jpg
# 2025-07-16 04:11:01,863 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:03,809 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169999.jpg
# 2025-07-16 04:11:03,812 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:05,065 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169989.jpg
# 2025-07-16 04:11:05,069 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:05,601 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169957.jpg
# 2025-07-16 04:11:05,603 - src.scraper.telegram_scraper - INFO - Scraped 900 messages from tikvahpharma
# 2025-07-16 04:11:05,606 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:07,684 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169938.jpg
# 2025-07-16 04:11:07,690 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:08,440 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169927.jpg
# 2025-07-16 04:11:08,445 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:10,049 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169887.jpg
# 2025-07-16 04:11:10,054 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:10,594 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169867.jpg
# 2025-07-16 04:11:10,600 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:10,897 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169864.jpg
# 2025-07-16 04:11:10,903 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:12,371 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169837.jpg
# 2025-07-16 04:11:12,376 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:14,064 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169820.jpg
# 2025-07-16 04:11:14,069 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:14,259 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169819.jpg
# 2025-07-16 04:11:14,267 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:15,897 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169797.jpg
# 2025-07-16 04:11:15,900 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:17,632 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169772.jpg
# 2025-07-16 04:11:17,636 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:18,338 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169764.jpg
# 2025-07-16 04:11:18,342 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:19,649 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169763.jpg
# 2025-07-16 04:11:19,655 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:20,114 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169757.jpg
# 2025-07-16 04:11:20,119 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 04:11:20,603 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169756.jpg
# 2025-07-16 04:11:20,609 - src.scraper.telegram_scraper - INFO - Successfully scraped 948 messages from tikvahpharma
# 2025-07-16 04:11:20,678 - src.scraper.telegram_scraper - INFO - Saved 948 messages to data/raw/telegram_messages\2025-07-16\tikvahpharma\tikvahpharma.json
# 2025-07-16 04:11:20,679 - src.scraper.telegram_scraper - INFO - Completed scraping tikvahpharma: 948 messages in 296.18s
# 2025-07-16 04:11:22,683 - src.scraper.telegram_scraper - INFO - Scraping completed in 1188.24s. 3/3 channels successful. Total messages scraped: 1975
# 2025-07-16 04:11:22,685 - dagster.builtin - INFO - Successfully scraped 63 messages from CheMed123
# 2025-07-16 04:11:22,687 - dagster.builtin - INFO - Successfully scraped 964 messages from lobelia4cosmetics
# 2025-07-16 04:11:22,691 - dagster.builtin - INFO - Successfully scraped 948 messages from tikvahpharma
# 2025-07-16 04:11:22,694 - telethon.network.mtprotosender - INFO - Disconnecting from 149.154.167.91:443/TcpFull...
# 2025-07-16 04:11:22,697 - telethon.network.mtprotosender - INFO - Disconnection from 149.154.167.91:443/TcpFull complete!
# 2025-07-16 04:11:22,704 - src.scraper.telegram_scraper - INFO - Disconnected from Telegram
# 2025-07-16 04:11:22,705 - dagster.builtin - INFO - Scraping completed: {'status': 'success', 'message_count': 1975, 'channels_processed': 3, 'successful_channels': 3, 'scrape_results': [{'channel_name': 'CheMed123', 'channel_url': 'https://t.me/CheMed123', 'message_count': 63, 'file_path': 'data/raw/telegram_messages\\2025-07-16\\CheMed123\\CheMed123.json', 'status': 'success', 'error': None, 'start_time': '2025-07-16T03:51:34.442427', 'end_time': '2025-07-16T03:53:25.973036', 'duration_seconds': 111.530609}, {'channel_name': 'lobelia4cosmetics', 'channel_url': 'https://t.me/lobelia4cosmetics', 'message_count': 964, 'file_path': 'data/raw/telegram_messages\\2025-07-16\\lobelia4cosmetics\\lobelia4cosmetics.json', 'status': 'success', 'error': None, 'start_time': '2025-07-16T03:53:28.005161', 'end_time': '2025-07-16T04:06:22.369034', 'duration_seconds': 774.363873}, {'channel_name': 'tikvahpharma', 'channel_url': 'https://t.me/tikvahpharma', 'message_count': 948, 'file_path': 'data/raw/telegram_messages\\2025-07-16\\tikvahpharma\\tikvahpharma.json', 'status': 'success', 'error': None, 'start_time': '2025-07-16T04:06:24.431646', 'end_time': '2025-07-16T04:11:20.611615', 'duration_seconds': 296.179969}]}
# ✅ Scraping operation completed!
# Status: success
# Messages scraped: 1975
# Channels processed: 3

# %% [markdown]
# Test Loading Operation

# %%
# Test loading operation
print("🧪 Testing Loading Operation")
print("=" * 50)

try:
    # Create a test context
    context = build_op_context()
    
    # Mock scrape results for testing
    mock_scrape_results = {
        'status': 'success',
        'message_count': 0,
        'channels_processed': 0
    }
    
    # Test the loading operation
    result = load_raw_to_postgres(context, mock_scrape_results)
    
    print(f"✅ Loading operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Records loaded: {result.get('records_loaded', 0)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ Loading test failed: {e}")
    print("This might be due to:")
    print("- Database connection issues")
    print("- Missing database tables")
    print("- Incorrect database URL")
# Out:
# 🧪 Testing Loading Operation
# ==================================================
# 2025-07-16 04:11:22,783 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:22,785 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:23,912 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:23,922 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:23,924 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:23,999 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:24,004 - dagster.builtin - INFO - Starting raw data loading to PostgreSQL
# Connected to PostgreSQL successfully
# Error loading messages: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# 2025-07-16 04:11:24,122 - dagster.builtin - ERROR - Error loading file CheMed123.json: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# Error loading messages: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# 2025-07-16 04:11:24,158 - dagster.builtin - ERROR - Error loading file lobelia4cosmetics.json: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# Error loading messages: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# 2025-07-16 04:11:24,200 - dagster.builtin - ERROR - Error loading file tikvahpharma.json: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# Error loading messages: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# 2025-07-16 04:11:24,224 - dagster.builtin - ERROR - Error loading file CheMed123.json: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# Error loading messages: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# 2025-07-16 04:11:24,253 - dagster.builtin - ERROR - Error loading file lobelia4cosmetics.json: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# Error loading messages: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
# 2025-07-16 04:11:24,305 - dagster.builtin - ERROR - Error loading file tikvahpharma.json: column "media_type" of relation "raw_messages" does not exist
# LINE 4: ...           message_text, message_date, has_media, media_type...
#                                                              ^
#
# 2025-07-16 04:11:24,307 - dagster.builtin - INFO - Raw data loading completed: {'status': 'success', 'records_loaded': 0, 'files_processed': 0}
# ✅ Loading operation completed!
# Status: success
# Records loaded: 0

# %% [markdown]
# Test DBT Operation

# %%
# Test dbt operation
print("🧪 Testing DBT Transformations")
print("=" * 50)

try:
    # Create a test context
    context = build_op_context()
    
    # Test the dbt operation
    result = run_dbt_transformations(context)
    
    print(f"✅ DBT operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Debug success: {result.get('debug_success', False)}")
    print(f"Run success: {result.get('run_success', False)}")
    print(f"Test success: {result.get('test_success', False)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ DBT test failed: {e}")
    print("This might be due to:")
    print("- Missing dbt configuration")
    print("- Database connection issues")
    print("- Missing dbt models")
# Out:
# 🧪 Testing DBT Transformations
# ==================================================
# 2025-07-16 04:11:24,360 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:24,361 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:24,451 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:24,466 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:24,467 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:24,563 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:24,567 - dagster.builtin - INFO - Starting dbt transformations
# 2025-07-16 04:11:24,569 - dagster.builtin - INFO - Running dbt debug...
# 2025-07-16 04:11:24,578 - dagster.builtin - ERROR - dbt debug failed: [WinError 2] The system cannot find the file specified
# ✅ DBT operation completed!
# Status: failed
# Debug success: False
# Run success: False
# Test success: False
# ❌ Error: dbt configuration error

# %% [markdown]
# Test YOLO Operation

# %%
# Test YOLO operation
print("🧪 Testing YOLO Enrichment")
print("=" * 50)

try:
    # Create a test context
    context = build_op_context()
    
    # Test the YOLO operation
    result = run_yolo_enrichment(context)
    
    print(f"✅ YOLO operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Images processed: {result.get('images_processed', 0)}")
    print(f"Detections found: {result.get('detections_found', 0)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ YOLO test failed: {e}")
    print("This might be due to:")
    print("- Missing YOLO model files")
    print("- No images found for processing")
    print("- GPU/CUDA issues")
# Out:
# 🧪 Testing YOLO Enrichment
# ==================================================
# 2025-07-16 04:11:24,639 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:24,642 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:24,730 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:24,742 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:24,743 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:24,824 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:24,831 - dagster.builtin - INFO - Starting YOLO image enrichment
# 2025-07-16 04:11:24,849 - dagster.builtin - INFO - Processing 2535 images with YOLO
# Error loading YOLO model: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# 2025-07-16 04:11:24,882 - dagster.builtin - ERROR - Error in run_yolo_enrichment: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# ❌ YOLO test failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# This might be due to:
# - Missing YOLO model files
# - No images found for processing
# - GPU/CUDA issues

# %% [markdown]
# ## Full Pipeline Execution
#
# Now let's run the complete pipeline and see how all operations work together.

# %%
# Execute the full pipeline
print("🚀 Executing Full Pipeline")
print("=" * 50)

try:
    # Execute the job
    result = execute_job(telegram_pipeline_job)
    
    if result.success:
        print("✅ Pipeline executed successfully!")
        print(f"Run ID: {result.run_id}")
        
        # Get execution summary
        for event in result.all_events:
            if event.event_type_value == "STEP_SUCCESS":
                print(f"✅ Step {event.step_key} completed successfully")
            elif event.event_type_value == "STEP_FAILURE":
                print(f"❌ Step {event.step_key} failed")
                print(f"   Error: {event}")
    
    else:
        print("❌ Pipeline execution failed!")
        for event in result.all_events:
            if event.event_type_value == "STEP_FAILURE":
                print(f"❌ Step {event.step_key} failed: {event}")
    
except Exception as e:
    print(f"❌ Pipeline execution error: {e}")
    print("Check your environment configuration and try again.")
# Out:
# 🚀 Executing Full Pipeline
# ==================================================
# ❌ Pipeline execution error: execute_job() missing 1 required positional argument: 'instance'
# Check your environment configuration and try again.

# %% [markdown]
# ## Pipeline Monitoring and Reporting
#
# Let's examine the pipeline results and generate reports.

# %%
# Analyze pipeline results
print("📊 Pipeline Results Analysis")
print("=" * 50)

try:
    # Get the latest run from Dagster instance
    instance = DagsterInstance.ephemeral()
    
    # List recent runs
    runs = instance.get_runs(limit=5)
    
    if runs:
        print(f"📈 Recent Pipeline Runs:")
        for run in runs:
            status = "✅ SUCCESS" if run.status.value == "SUCCESS" else "❌ FAILED"
            print(f"   {run.run_id[:8]}... - {status} - {run.start_time}")
        
        # Get the most recent run
        latest_run = runs[0]
        print(f"\n�� Latest Run Details:")
        print(f"   Run ID: {latest_run.run_id}")
        print(f"   Status: {latest_run.status.value}")
        print(f"   Start Time: {latest_run.start_time}")
        print(f"   End Time: {latest_run.end_time}")
        
        if latest_run.status.value == "SUCCESS":
            print("   ✅ Pipeline completed successfully!")
        else:
            print("   ❌ Pipeline failed - check logs for details")
    
    else:
        print("📭 No pipeline runs found")
        print("Run the pipeline first to see results")
        
except Exception as e:
    print(f"❌ Error analyzing results: {e}")
# Out:
# 📊 Pipeline Results Analysis
# ==================================================
# 2025-07-16 04:11:24,966 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:24,969 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:25,060 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 04:11:25,071 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 04:11:25,074 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 04:11:25,159 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 📭 No pipeline runs found
# Run the pipeline first to see results

# %% [markdown]
# ## Configuration and Customization
#
# Learn how to customize the pipeline for your specific needs.

# %%
# Show pipeline configuration options
print("⚙️  Pipeline Configuration")
print("=" * 50)

# Get default configuration
from dags.telegram_pipeline import get_pipeline_config

config = get_pipeline_config()
print("📋 Default Configuration:")
for op_name, op_config in config.get('ops', {}).items():
    print(f"   {op_name}:")
    for key, value in op_config.get('config', {}).items():
        print(f"     {key}: {value}")

print("\n🔧 Customization Options:")
print("   1. Modify scrape_telegram_data config for different channels")
print("   2. Adjust load_raw_to_postgres batch sizes")
print("   3. Configure dbt project settings")
print("   4. Set YOLO confidence thresholds")
print("   5. Add custom schedules")

# Example: Custom configuration
print("\n💡 Example Custom Configuration:")
custom_config = {
    "ops": {
        "scrape_telegram_data": {
            "config": {
                "max_messages_per_channel": 500,  # Reduced from 1000
                "include_media": True
            }
        },
        "run_yolo_enrichment": {
            "config": {
                "confidence_threshold": 0.7,  # Increased from 0.5
                "model_path": "models/custom_yolo.pt"
            }
        }
    }
}
print("   Custom config created for testing")
# Out:
# ⚙️  Pipeline Configuration
# ==================================================
# 📋 Default Configuration:
#    scrape_telegram_data:
#      max_messages_per_channel: 1000
#      include_media: True
#    load_raw_to_postgres:
#      batch_size: 1000
#      retry_attempts: 3
#    run_dbt_transformations:
#      dbt_project_dir: dbt
#      profiles_dir: dbt
#    run_yolo_enrichment:
#      confidence_threshold: 0.5
#      model_path: models/yolo_medical.pt
#
# 🔧 Customization Options:
#    1. Modify scrape_telegram_data config for different channels
#    2. Adjust load_raw_to_postgres batch sizes
#    3. Configure dbt project settings
#    4. Set YOLO confidence thresholds
#    5. Add custom schedules
#
# 💡 Example Custom Configuration:
#    Custom config created for testing

# %% [markdown]
# ## Troubleshooting and Debugging
#
# Common issues and how to resolve them.

# %%
# Troubleshooting guide
print("🔧 Troubleshooting Guide")
print("=" * 50)

troubleshooting = {
    "Telegram Connection Issues": [
        "Check TELEGRAM_API_ID and TELEGRAM_API_HASH in .env",
        "Verify phone number format (+1234567890)",
        "Ensure internet connectivity",
        "Check for rate limiting"
    ],
    "Database Connection Issues": [
        "Verify DATABASE_URL format",
        "Check PostgreSQL is running",
        "Ensure database exists",
        "Check user permissions"
    ],
    "dbt Issues": [
        "Run 'dbt debug' to check configuration",
        "Verify dbt project structure",
        "Check profiles.yml setup",
        "Ensure dbt dependencies installed"
    ],
    "YOLO Issues": [
        "Check YOLO model files exist",
        "Verify CUDA/GPU setup",
        "Check image file paths",
        "Ensure ultralytics is installed"
    ],
    "Dagster Issues": [
        "Check dagster.yaml configuration",
        "Verify workspace setup",
        "Check Python environment",
        "Review Dagster logs"
    ]
}

for issue, solutions in troubleshooting.items():
    print(f"\n❓ {issue}:")
    for i, solution in enumerate(solutions, 1):
        print(f"   {i}. {solution}")

print("\n📞 For more help:")
print("   - Check Dagster documentation")
print("   - Review pipeline logs")
print("   - Test individual operations")
# Out:
# 🔧 Troubleshooting Guide
# ==================================================
#
# ❓ Telegram Connection Issues:
#    1. Check TELEGRAM_API_ID and TELEGRAM_API_HASH in .env
#    2. Verify phone number format (+1234567890)
#    3. Ensure internet connectivity
#    4. Check for rate limiting
#
# ❓ Database Connection Issues:
#    1. Verify DATABASE_URL format
#    2. Check PostgreSQL is running
#    3. Ensure database exists
#    4. Check user permissions
#
# ❓ dbt Issues:
#    1. Run 'dbt debug' to check configuration
#    2. Verify dbt project structure
#    3. Check profiles.yml setup
#    4. Ensure dbt dependencies installed
#
# ❓ YOLO Issues:
#    1. Check YOLO model files exist
#    2. Verify CUDA/GPU setup
#    3. Check image file paths
#    4. Ensure ultralytics is installed
#
# ❓ Dagster Issues:
#    1. Check dagster.yaml configuration
#    2. Verify workspace setup
#    3. Check Python environment
#    4. Review Dagster logs
#
# 📞 For more help:
#    - Check Dagster documentation
#    - Review pipeline logs
#    - Test individual operations

# %% [markdown]
# ## Next Steps
#
# Your Dagster pipeline is now ready for production use!

# %%
# Next steps and recommendations
print("�� Next Steps")
print("=" * 50)

next_steps = [
    "1. Set up production environment variables",
    "2. Configure database for production use",
    "3. Set up monitoring and alerting",
    "4. Create custom schedules for automation",
    "5. Add data quality checks",
    "6. Implement error handling and retries",
    "7. Set up logging and metrics collection",
    "8. Create backup and recovery procedures"
]

for step in next_steps:
    print(f"   {step}")

print("\n🚀 Ready to deploy!")
print("   Your Dagster pipeline is configured and ready for production use.")
print("   Use 'dagster dev' to start the UI and monitor your pipelines.")
# Out:
# �� Next Steps
# ==================================================
#    1. Set up production environment variables
#    2. Configure database for production use
#    3. Set up monitoring and alerting
#    4. Create custom schedules for automation
#    5. Add data quality checks
#    6. Implement error handling and retries
#    7. Set up logging and metrics collection
#    8. Create backup and recovery procedures
#
# 🚀 Ready to deploy!
#    Your Dagster pipeline is configured and ready for production use.
#    Use 'dagster dev' to start the UI and monitor your pipelines.
