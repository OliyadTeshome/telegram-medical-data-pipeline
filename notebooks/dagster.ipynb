# %% [markdown]
# # Dagster Pipeline for Telegram Medical Data
#
# This notebook demonstrates how to use the Dagster pipeline for processing Telegram medical data.
#
# ## Overview
# The pipeline consists of the following operations:
# 1. **scrape_telegram_data**: Scrapes data from Telegram channels using Telethon
# 2. **load_raw_to_postgres**: Loads raw data to PostgreSQL
# 3. **run_dbt_transformations**: Runs dbt transformations
# 4. **run_yolo_enrichment**: Processes images with YOLO
# 5. **generate_pipeline_report**: Creates execution reports
#
# ## Setup
# Make sure you have:
# - All dependencies installed in your environment
# - Environment variables configured (.env file)
# - PostgreSQL database running

# %% [markdown]
# Imports and Setup

# %%
# Import required libraries
import sys
import os
from pathlib import Path

# Add project root to Python path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# Import Dagster components
from dagster import (
    execute_job, 
    DagsterInstance, 
    get_dagster_logger,
    job, 
    op
)

# Import pipeline components
from dags.telegram_pipeline import (
    telegram_pipeline_job,
    scrape_telegram_data,
    load_raw_to_postgres,
    run_dbt_transformations,
    run_yolo_enrichment,
    generate_pipeline_report
)

# Import source modules
from src.scraper.telegram_scraper import TelegramScraper
from src.loader.postgres_loader import PostgresLoader
from src.enrich.yolo_enricher import YOLOEnricher
from src.dbt_runner.dbt_executor import DBTExecutor
from src.utils.config import get_config

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## Environment Check
#
# Let's verify that our environment is properly configured and all components are working.

# %%
# Check environment variables
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Required environment variables
required_vars = [
    'TELEGRAM_API_ID',
    'TELEGRAM_API_HASH', 
    'TELEGRAM_PHONE'
]

print("🔍 Checking Environment Variables:")
print("=" * 50)

missing_vars = []
for var in required_vars:
    value = os.getenv(var)
    if value:
        # Mask sensitive values
        if 'API' in var or 'HASH' in var or 'PASSWORD' in var:
            display_value = value[:4] + "..." + value[-4:] if len(value) > 8 else "***"
        else:
            display_value = value
        print(f"✅ {var}: {display_value}")
    else:
        print(f"❌ {var}: NOT SET")
        missing_vars.append(var)

if missing_vars:
    print(f"\n⚠️  Missing environment variables: {missing_vars}")
    print("Please set these in your .env file")
else:
    print("\n✅ All required environment variables are set!")

# Check Dagster instance
try:
    instance = DagsterInstance.ephemeral()
    print("✅ Dagster instance created successfully")
except Exception as e:
    print(f"❌ Dagster instance error: {e}")
# Out:
# 🔍 Checking Environment Variables:
# ==================================================
# ✅ TELEGRAM_API_ID: ***
# ✅ TELEGRAM_API_HASH: 041e...b3e7
# ✅ TELEGRAM_PHONE: +251715349456
#
# ✅ All required environment variables are set!
# 2025-07-16 03:13:20,982 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:13:20,982 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:13:21,040 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:13:21,056 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:13:21,056 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:13:21,124 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# ✅ Dagster instance created successfully

# %% [markdown]
# ## Pipeline Components Overview
#
# Let's examine the individual operations that make up our pipeline.

# %%
# Display pipeline structure
print("📋 Pipeline Components:")
print("=" * 50)

components = [
    ("scrape_telegram_data", "Scrapes Telegram channels for medical data"),
    ("load_raw_to_postgres", "Loads raw data to PostgreSQL database"),
    ("run_dbt_transformations", "Runs dbt models and transformations"),
    ("run_yolo_enrichment", "Processes images with YOLO for medical content"),
    ("generate_pipeline_report", "Creates comprehensive execution report")
]

for i, (name, description) in enumerate(components, 1):
    print(f"{i}. {name}")
    print(f"   └─ {description}")

print(f"\n�� Main Job: telegram_pipeline_job")
print("   └─ Orchestrates all operations in sequence")

# Show job definition
print(f"\n�� Job Definition:")
print(f"   {telegram_pipeline_job.__doc__}")
# Out:
# 📋 Pipeline Components:
# ==================================================
# 1. scrape_telegram_data
#    └─ Scrapes Telegram channels for medical data
# 2. load_raw_to_postgres
#    └─ Loads raw data to PostgreSQL database
# 3. run_dbt_transformations
#    └─ Runs dbt models and transformations
# 4. run_yolo_enrichment
#    └─ Processes images with YOLO for medical content
# 5. generate_pipeline_report
#    └─ Creates comprehensive execution report
#
# �� Main Job: telegram_pipeline_job
#    └─ Orchestrates all operations in sequence
#
# �� Job Definition:
#
#     Main Dagster job for the Telegram medical data pipeline.
#
#     This job orchestrates the following operations:
#     1. scrape_telegram_data: Scrapes data from Telegram channels
#     2. load_raw_to_postgres: Loads raw data to PostgreSQL
#     3. run_dbt_transformations: Runs dbt transformations
#     4. run_yolo_enrichment: Processes images with YOLO
#     5. generate_pipeline_report: Generates execution report

# %% [markdown]
# ## Individual Operation Testing
#
# Let's test each operation individually to ensure they work correctly.

# %% [markdown]
# Test Scraping Operation

# %%
# Test scraping operation
print("🧪 Testing Scraping Operation")
print("=" * 50)

try:
    # Create a test context
    from dagster import build_op_context
    
    context = build_op_context()
    
    # Test the scraping operation
    result = scrape_telegram_data(context)
    
    print(f"✅ Scraping operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Messages scraped: {result.get('message_count', 0)}")
    print(f"Channels processed: {result.get('channels_processed', 0)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ Scraping test failed: {e}")
    print("This might be due to:")
    print("- Missing Telegram credentials")
    print("- Network connectivity issues")
    print("- Rate limiting from Telegram")
# Out:
# 🧪 Testing Scraping Operation
# ==================================================
# 2025-07-16 03:13:21,232 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:13:21,236 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:13:21,312 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:13:21,324 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:13:21,324 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:13:21,413 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:13:21,415 - dagster.builtin - INFO - Starting Telegram data scraping operation
# 2025-07-16 03:13:21,422 - src.scraper.telegram_scraper - INFO - Initialized TelegramScraper with 3 target channels
# 2025-07-16 03:13:21,424 - telethon.network.mtprotosender - INFO - Connecting to 149.154.167.91:443/TcpFull...
# 2025-07-16 03:13:21,571 - telethon.network.mtprotosender - INFO - Connection to 149.154.167.91:443/TcpFull complete!
# 2025-07-16 03:13:22,442 - src.scraper.telegram_scraper - INFO - Successfully connected to Telegram
# 2025-07-16 03:13:22,443 - dagster.builtin - INFO - Successfully connected to Telegram
# 2025-07-16 03:13:22,443 - src.scraper.telegram_scraper - INFO - Starting scrape for 3 channels
# 2025-07-16 03:13:22,443 - src.scraper.telegram_scraper - INFO - Starting scrape for channel: CheMed123
# 2025-07-16 03:13:22,443 - src.scraper.telegram_scraper - INFO - Starting to scrape channel: CheMed123
# 2025-07-16 03:13:22,980 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:23,639 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\97.jpg
# 2025-07-16 03:13:23,641 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:24,700 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\96.jpg
# 2025-07-16 03:13:24,700 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:25,658 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\95.jpg
# 2025-07-16 03:13:25,662 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:26,539 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\94.jpg
# 2025-07-16 03:13:26,543 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:27,723 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\93.jpg
# 2025-07-16 03:13:27,738 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:28,895 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\92.jpg
# 2025-07-16 03:13:28,899 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:29,597 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\91.jpg
# 2025-07-16 03:13:29,597 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:31,439 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\90.jpg
# 2025-07-16 03:13:31,439 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:32,505 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\88.jpg
# 2025-07-16 03:13:32,505 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:33,725 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\87.jpg
# 2025-07-16 03:13:33,725 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:35,038 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\86.jpg
# 2025-07-16 03:13:35,038 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:35,845 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\85.jpg
# 2025-07-16 03:13:35,845 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:36,607 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\82.jpg
# 2025-07-16 03:13:36,607 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:37,972 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\81.jpg
# 2025-07-16 03:13:37,972 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:38,790 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\80.jpg
# 2025-07-16 03:13:38,790 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:39,971 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\79.jpg
# 2025-07-16 03:13:39,987 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:41,171 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\77.jpg
# 2025-07-16 03:13:41,184 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:42,157 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\76.jpg
# 2025-07-16 03:13:42,161 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:43,222 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\75.jpg
# 2025-07-16 03:13:43,222 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:44,221 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\71.jpg
# 2025-07-16 03:13:44,221 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:45,288 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\70.jpg
# 2025-07-16 03:13:45,302 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:46,442 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\67.jpg
# 2025-07-16 03:13:46,442 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:47,655 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\64.jpg
# 2025-07-16 03:13:47,655 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:48,255 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\60.jpg
# 2025-07-16 03:13:48,255 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:48,972 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\59.jpg
# 2025-07-16 03:13:48,972 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:49,356 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\58.jpg
# 2025-07-16 03:13:49,358 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:50,506 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\55.jpg
# 2025-07-16 03:13:50,508 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:51,405 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\52.jpg
# 2025-07-16 03:13:51,410 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:52,130 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\50.jpg
# 2025-07-16 03:13:52,130 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:52,729 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\49.jpg
# 2025-07-16 03:13:52,729 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:53,944 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\48.jpg
# 2025-07-16 03:13:53,944 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:54,873 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\46.jpg
# 2025-07-16 03:13:54,873 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:55,705 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\45.jpg
# 2025-07-16 03:13:55,707 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:56,655 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\43.jpg
# 2025-07-16 03:13:56,655 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:57,560 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\41.jpg
# 2025-07-16 03:13:57,560 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:58,161 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\40.jpg
# 2025-07-16 03:13:58,161 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:58,756 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\39.jpg
# 2025-07-16 03:13:58,759 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:59,396 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\38.jpg
# 2025-07-16 03:13:59,405 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:13:59,921 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\34.jpg
# 2025-07-16 03:13:59,927 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:00,938 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\33.jpg
# 2025-07-16 03:14:00,943 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:01,646 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\31.jpg
# 2025-07-16 03:14:01,655 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:02,194 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\30.jpg
# 2025-07-16 03:14:02,194 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:02,875 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\27.jpg
# 2025-07-16 03:14:02,887 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:04,157 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\26.jpg
# 2025-07-16 03:14:04,163 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:04,753 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\25.jpg
# 2025-07-16 03:14:04,753 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:05,399 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\23.jpg
# 2025-07-16 03:14:05,406 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:06,058 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\22.jpg
# 2025-07-16 03:14:06,074 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:06,729 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\21.jpg
# 2025-07-16 03:14:06,729 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:08,059 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\20.jpg
# 2025-07-16 03:14:08,059 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:09,572 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\19.jpg
# 2025-07-16 03:14:09,572 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:10,482 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\18.jpg
# 2025-07-16 03:14:10,482 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:11,278 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\17.jpg
# 2025-07-16 03:14:11,278 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:11,955 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\15.jpg
# 2025-07-16 03:14:11,969 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:13,112 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\14.jpg
# 2025-07-16 03:14:13,112 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:14,540 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\13.jpg
# 2025-07-16 03:14:14,544 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:15,375 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\11.jpg
# 2025-07-16 03:14:15,391 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:16,583 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\10.jpg
# 2025-07-16 03:14:16,612 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:17,223 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\9.jpg
# 2025-07-16 03:14:17,226 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:17,673 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\CheMed123\2.jpg
# 2025-07-16 03:14:17,673 - src.scraper.telegram_scraper - INFO - Successfully scraped 63 messages from CheMed123
# 2025-07-16 03:14:17,680 - src.scraper.telegram_scraper - INFO - Saved 63 messages to data/raw/telegram_messages\2025-07-16\CheMed123\CheMed123.json
# 2025-07-16 03:14:17,680 - src.scraper.telegram_scraper - INFO - Completed scraping CheMed123: 63 messages in 55.23s
# 2025-07-16 03:14:19,693 - src.scraper.telegram_scraper - INFO - Starting scrape for channel: lobelia4cosmetics
# 2025-07-16 03:14:19,693 - src.scraper.telegram_scraper - INFO - Starting to scrape channel: lobelia4cosmetics
# 2025-07-16 03:14:20,444 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:21,077 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18584.jpg
# 2025-07-16 03:14:21,087 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:21,810 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18583.jpg
# 2025-07-16 03:14:21,810 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:22,554 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18582.jpg
# 2025-07-16 03:14:22,570 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:22,870 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18581.jpg
# 2025-07-16 03:14:22,870 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:23,525 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18580.jpg
# 2025-07-16 03:14:23,525 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:23,850 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18579.jpg
# 2025-07-16 03:14:23,855 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:25,243 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18578.jpg
# 2025-07-16 03:14:25,254 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:25,919 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18577.jpg
# 2025-07-16 03:14:25,919 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:26,623 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18575.jpg
# 2025-07-16 03:14:26,642 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:27,096 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18574.jpg
# 2025-07-16 03:14:27,108 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:27,538 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18573.jpg
# 2025-07-16 03:14:27,551 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:27,813 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18572.jpg
# 2025-07-16 03:14:27,813 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:28,507 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18571.jpg
# 2025-07-16 03:14:28,509 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:28,778 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18570.jpg
# 2025-07-16 03:14:28,778 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:29,358 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18569.jpg
# 2025-07-16 03:14:29,358 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:30,125 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18568.jpg
# 2025-07-16 03:14:30,125 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:30,889 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18567.jpg
# 2025-07-16 03:14:30,905 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:31,638 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18566.jpg
# 2025-07-16 03:14:31,638 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:32,371 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18565.jpg
# 2025-07-16 03:14:32,378 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:32,889 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18564.jpg
# 2025-07-16 03:14:32,889 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:35,006 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18563.jpg
# 2025-07-16 03:14:35,012 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:35,322 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18562.jpg
# 2025-07-16 03:14:35,322 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:35,903 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18561.jpg
# 2025-07-16 03:14:35,903 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:36,426 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18560.jpg
# 2025-07-16 03:14:36,433 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:36,818 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18559.jpg
# 2025-07-16 03:14:36,823 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:37,175 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18558.jpg
# 2025-07-16 03:14:37,189 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:38,024 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18557.jpg
# 2025-07-16 03:14:38,024 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:39,433 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18556.jpg
# 2025-07-16 03:14:39,444 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:40,628 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18555.jpg
# 2025-07-16 03:14:40,628 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:41,121 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18554.jpg
# 2025-07-16 03:14:41,121 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:42,611 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18553.jpg
# 2025-07-16 03:14:42,611 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:43,006 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18552.jpg
# 2025-07-16 03:14:43,006 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:43,442 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18551.jpg
# 2025-07-16 03:14:43,446 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:44,179 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18550.jpg
# 2025-07-16 03:14:44,193 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:44,826 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18549.jpg
# 2025-07-16 03:14:44,842 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:45,545 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18548.jpg
# 2025-07-16 03:14:45,556 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:45,786 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18547.jpg
# 2025-07-16 03:14:45,786 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:46,311 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18546.jpg
# 2025-07-16 03:14:46,311 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:46,762 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18545.jpg
# 2025-07-16 03:14:46,762 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:47,094 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18544.jpg
# 2025-07-16 03:14:47,094 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:47,457 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18543.jpg
# 2025-07-16 03:14:47,462 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:47,742 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18542.jpg
# 2025-07-16 03:14:47,753 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:48,079 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18541.jpg
# 2025-07-16 03:14:48,087 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:48,442 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18540.jpg
# 2025-07-16 03:14:48,442 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:48,712 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18539.jpg
# 2025-07-16 03:14:48,712 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:49,137 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18538.jpg
# 2025-07-16 03:14:49,144 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:49,476 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18537.jpg
# 2025-07-16 03:14:49,476 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:49,732 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18536.jpg
# 2025-07-16 03:14:49,734 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:50,259 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18535.jpg
# 2025-07-16 03:14:50,276 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:50,944 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18534.jpg
# 2025-07-16 03:14:50,944 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:51,203 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18533.jpg
# 2025-07-16 03:14:51,205 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:51,638 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18532.jpg
# 2025-07-16 03:14:51,639 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:51,906 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18531.jpg
# 2025-07-16 03:14:51,906 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:52,430 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18530.jpg
# 2025-07-16 03:14:52,430 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:52,673 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18529.jpg
# 2025-07-16 03:14:52,673 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:52,874 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18528.jpg
# 2025-07-16 03:14:52,874 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:53,605 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18526.jpg
# 2025-07-16 03:14:53,611 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:53,995 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18525.jpg
# 2025-07-16 03:14:54,005 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:54,728 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18524.jpg
# 2025-07-16 03:14:54,738 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:55,045 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18522.jpg
# 2025-07-16 03:14:55,047 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:55,570 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18521.jpg
# 2025-07-16 03:14:55,575 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:56,660 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18520.jpg
# 2025-07-16 03:14:56,670 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:58,059 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18519.jpg
# 2025-07-16 03:14:58,075 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:58,393 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18518.jpg
# 2025-07-16 03:14:58,393 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:58,613 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18517.jpg
# 2025-07-16 03:14:58,613 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:58,867 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18516.jpg
# 2025-07-16 03:14:58,870 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:59,611 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18515.jpg
# 2025-07-16 03:14:59,611 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:14:59,844 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18514.jpg
# 2025-07-16 03:14:59,844 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:00,139 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18513.jpg
# 2025-07-16 03:15:00,139 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:00,494 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18512.jpg
# 2025-07-16 03:15:00,496 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:00,810 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18511.jpg
# 2025-07-16 03:15:00,810 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:01,278 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18510.jpg
# 2025-07-16 03:15:01,294 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:01,581 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18509.jpg
# 2025-07-16 03:15:01,583 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:01,774 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18507.jpg
# 2025-07-16 03:15:01,774 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:02,472 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18506.jpg
# 2025-07-16 03:15:02,472 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:03,205 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18505.jpg
# 2025-07-16 03:15:03,205 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:03,889 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18504.jpg
# 2025-07-16 03:15:03,889 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:04,562 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18503.jpg
# 2025-07-16 03:15:04,567 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:05,139 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18502.jpg
# 2025-07-16 03:15:05,149 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:05,838 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18501.jpg
# 2025-07-16 03:15:05,838 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:06,172 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18500.jpg
# 2025-07-16 03:15:06,172 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:06,955 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18499.jpg
# 2025-07-16 03:15:06,955 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:07,440 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18498.jpg
# 2025-07-16 03:15:07,440 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:07,741 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18497.jpg
# 2025-07-16 03:15:07,747 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:08,238 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18496.jpg
# 2025-07-16 03:15:08,238 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:08,759 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18495.jpg
# 2025-07-16 03:15:08,762 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:09,139 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18494.jpg
# 2025-07-16 03:15:09,139 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:09,433 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18493.jpg
# 2025-07-16 03:15:09,438 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:09,716 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18492.jpg
# 2025-07-16 03:15:09,721 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:10,910 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18491.jpg
# 2025-07-16 03:15:10,922 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:12,045 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18490.jpg
# 2025-07-16 03:15:12,054 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:12,325 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18489.jpg
# 2025-07-16 03:15:12,325 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:13,184 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18488.jpg
# 2025-07-16 03:15:13,189 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:13,476 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18487.jpg
# 2025-07-16 03:15:13,476 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:14,293 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18486.jpg
# 2025-07-16 03:15:14,293 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:15,019 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18485.jpg
# 2025-07-16 03:15:15,024 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:15,354 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18484.jpg
# 2025-07-16 03:15:15,367 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:16,139 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18483.jpg
# 2025-07-16 03:15:16,480 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:16,904 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18482.jpg
# 2025-07-16 03:15:16,909 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:18,123 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18481.jpg
# 2025-07-16 03:15:18,123 - src.scraper.telegram_scraper - INFO - Scraped 100 messages from lobelia4cosmetics
# 2025-07-16 03:15:18,129 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:19,289 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18480.jpg
# 2025-07-16 03:15:19,289 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:19,626 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18479.jpg
# 2025-07-16 03:15:19,630 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:20,441 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18478.jpg
# 2025-07-16 03:15:20,441 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:20,939 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18477.jpg
# 2025-07-16 03:15:20,953 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:22,088 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18476.jpg
# 2025-07-16 03:15:22,088 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:22,515 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18475.jpg
# 2025-07-16 03:15:22,519 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:23,056 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18474.jpg
# 2025-07-16 03:15:23,069 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:15:23,459 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\lobelia4cosmetics\18473.jpg
# ...
# 2025-07-16 03:37:04,591 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170531.jpg
# 2025-07-16 03:37:04,594 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:05,295 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170512.jpg
# 2025-07-16 03:37:05,297 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:06,345 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170503.jpg
# 2025-07-16 03:37:06,352 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:07,341 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170495.jpg
# 2025-07-16 03:37:07,344 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:08,143 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170476.jpg
# 2025-07-16 03:37:08,150 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:08,461 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170455.jpg
# 2025-07-16 03:37:08,466 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:10,237 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170452.jpg
# 2025-07-16 03:37:10,243 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:11,196 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170434.jpg
# 2025-07-16 03:37:11,203 - src.scraper.telegram_scraper - INFO - Scraped 800 messages from tikvahpharma
# 2025-07-16 03:37:11,206 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:13,656 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170401.jpg
# 2025-07-16 03:37:13,659 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:13,877 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170378.jpg
# 2025-07-16 03:37:13,883 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:14,991 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170351.jpg
# 2025-07-16 03:37:14,996 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:16,443 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170343.jpg
# 2025-07-16 03:37:16,448 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:16,764 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170326.jpg
# 2025-07-16 03:37:16,772 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:18,606 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170315.jpg
# 2025-07-16 03:37:18,609 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:18,816 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170314.jpg
# 2025-07-16 03:37:18,821 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:19,007 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170310.jpg
# 2025-07-16 03:37:19,010 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:19,219 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170278.jpg
# 2025-07-16 03:37:19,223 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:20,281 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170276.jpg
# 2025-07-16 03:37:20,285 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:21,788 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170272.jpg
# 2025-07-16 03:37:21,792 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:23,019 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170270.jpg
# 2025-07-16 03:37:23,025 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:23,334 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170202.jpg
# 2025-07-16 03:37:23,339 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:24,897 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170195.jpg
# 2025-07-16 03:37:24,905 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:26,974 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170173.jpg
# 2025-07-16 03:37:26,981 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:27,792 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170168.jpg
# 2025-07-16 03:37:27,795 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:28,349 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170142.jpg
# 2025-07-16 03:37:29,206 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:30,270 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170128.jpg
# 2025-07-16 03:37:30,276 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:31,695 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170118.jpg
# 2025-07-16 03:37:31,700 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:33,812 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170098.jpg
# 2025-07-16 03:37:33,817 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:34,499 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170084.jpg
# 2025-07-16 03:37:34,509 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:36,445 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170056.jpg
# 2025-07-16 03:37:36,456 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:37,780 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170041.jpg
# 2025-07-16 03:37:37,788 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:39,630 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\170035.jpg
# 2025-07-16 03:37:39,647 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:42,476 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169999.jpg
# 2025-07-16 03:37:42,480 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:43,646 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169989.jpg
# 2025-07-16 03:37:43,651 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:44,137 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169957.jpg
# 2025-07-16 03:37:44,138 - src.scraper.telegram_scraper - INFO - Scraped 900 messages from tikvahpharma
# 2025-07-16 03:37:44,141 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:46,440 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169938.jpg
# 2025-07-16 03:37:46,444 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:47,131 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169927.jpg
# 2025-07-16 03:37:47,135 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:49,354 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169887.jpg
# 2025-07-16 03:37:49,361 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:50,308 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169867.jpg
# 2025-07-16 03:37:50,316 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:50,817 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169864.jpg
# 2025-07-16 03:37:50,826 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:53,089 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169837.jpg
# 2025-07-16 03:37:53,093 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:54,844 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169820.jpg
# 2025-07-16 03:37:54,848 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:55,090 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169819.jpg
# 2025-07-16 03:37:55,095 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:57,742 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169797.jpg
# 2025-07-16 03:37:57,748 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:37:59,699 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169772.jpg
# 2025-07-16 03:37:59,705 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:38:00,422 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169764.jpg
# 2025-07-16 03:38:00,425 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:38:01,628 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169763.jpg
# 2025-07-16 03:38:01,637 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:38:01,905 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169757.jpg
# 2025-07-16 03:38:01,909 - telethon.client.downloads - INFO - Starting direct file download in chunks of 131072 at 0, stride 131072
# 2025-07-16 03:38:02,407 - src.scraper.telegram_scraper - INFO - Downloaded image: data/raw/telegram_images\2025-07-16\tikvahpharma\169756.jpg
# 2025-07-16 03:38:02,414 - src.scraper.telegram_scraper - INFO - Successfully scraped 948 messages from tikvahpharma
# 2025-07-16 03:38:02,470 - src.scraper.telegram_scraper - INFO - Saved 948 messages to data/raw/telegram_messages\2025-07-16\tikvahpharma\tikvahpharma.json
# 2025-07-16 03:38:02,472 - src.scraper.telegram_scraper - INFO - Completed scraping tikvahpharma: 948 messages in 365.14s
# 2025-07-16 03:38:04,476 - src.scraper.telegram_scraper - INFO - Scraping completed in 1482.03s. 3/3 channels successful. Total messages scraped: 1975
# 2025-07-16 03:38:04,478 - dagster.builtin - INFO - Successfully scraped 63 messages from CheMed123
# 2025-07-16 03:38:04,483 - dagster.builtin - INFO - Successfully scraped 964 messages from lobelia4cosmetics
# 2025-07-16 03:38:04,486 - dagster.builtin - INFO - Successfully scraped 948 messages from tikvahpharma
# 2025-07-16 03:38:04,491 - telethon.network.mtprotosender - INFO - Disconnecting from 149.154.167.91:443/TcpFull...
# 2025-07-16 03:38:04,495 - telethon.network.mtprotosender - INFO - Disconnection from 149.154.167.91:443/TcpFull complete!
# 2025-07-16 03:38:04,509 - src.scraper.telegram_scraper - INFO - Disconnected from Telegram
# 2025-07-16 03:38:04,514 - dagster.builtin - INFO - Scraping completed: {'status': 'success', 'message_count': 1975, 'channels_processed': 3, 'successful_channels': 3, 'scrape_results': [{'channel_name': 'CheMed123', 'channel_url': 'https://t.me/CheMed123', 'message_count': 63, 'file_path': 'data/raw/telegram_messages\\2025-07-16\\CheMed123\\CheMed123.json', 'status': 'success', 'error': None, 'start_time': '2025-07-16T03:13:22.443715', 'end_time': '2025-07-16T03:14:17.677101', 'duration_seconds': 55.233386}, {'channel_name': 'lobelia4cosmetics', 'channel_url': 'https://t.me/lobelia4cosmetics', 'message_count': 964, 'file_path': 'data/raw/telegram_messages\\2025-07-16\\lobelia4cosmetics\\lobelia4cosmetics.json', 'status': 'success', 'error': None, 'start_time': '2025-07-16T03:14:19.693972', 'end_time': '2025-07-16T03:31:55.141069', 'duration_seconds': 1055.447097}, {'channel_name': 'tikvahpharma', 'channel_url': 'https://t.me/tikvahpharma', 'message_count': 948, 'file_path': 'data/raw/telegram_messages\\2025-07-16\\tikvahpharma\\tikvahpharma.json', 'status': 'success', 'error': None, 'start_time': '2025-07-16T03:31:57.276586', 'end_time': '2025-07-16T03:38:02.418687', 'duration_seconds': 365.142101}]}
# ✅ Scraping operation completed!
# Status: success
# Messages scraped: 1975
# Channels processed: 3

# %% [markdown]
# Test Loading Operation

# %%
# Test loading operation
print("🧪 Testing Loading Operation")
print("=" * 50)

try:
    # Create a test context
    context = build_op_context()
    
    # Mock scrape results for testing
    mock_scrape_results = {
        'status': 'success',
        'message_count': 0,
        'channels_processed': 0
    }
    
    # Test the loading operation
    result = load_raw_to_postgres(context, mock_scrape_results)
    
    print(f"✅ Loading operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Records loaded: {result.get('records_loaded', 0)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ Loading test failed: {e}")
    print("This might be due to:")
    print("- Database connection issues")
    print("- Missing database tables")
    print("- Incorrect database URL")
# Out:
# 🧪 Testing Loading Operation
# ==================================================
# 2025-07-16 03:38:04,584 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:04,587 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:04,665 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:04,677 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:04,679 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:04,772 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:04,777 - dagster.builtin - INFO - Starting raw data loading to PostgreSQL
# Connected to PostgreSQL successfully
# Error loading messages: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# 2025-07-16 03:38:04,909 - dagster.builtin - ERROR - Error loading file CheMed123.json: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# Error loading messages: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# 2025-07-16 03:38:04,942 - dagster.builtin - ERROR - Error loading file lobelia4cosmetics.json: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# Error loading messages: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# 2025-07-16 03:38:05,009 - dagster.builtin - ERROR - Error loading file tikvahpharma.json: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# Error loading messages: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# 2025-07-16 03:38:05,032 - dagster.builtin - ERROR - Error loading file CheMed123.json: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# Error loading messages: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# 2025-07-16 03:38:05,067 - dagster.builtin - ERROR - Error loading file lobelia4cosmetics.json: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# Error loading messages: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
# 2025-07-16 03:38:05,112 - dagster.builtin - ERROR - Error loading file tikvahpharma.json: relation "raw_messages" does not exist
# LINE 2:                     INSERT INTO raw_messages
#                                         ^
#
# 2025-07-16 03:38:05,114 - dagster.builtin - INFO - Raw data loading completed: {'status': 'success', 'records_loaded': 0, 'files_processed': 0}
# ✅ Loading operation completed!
# Status: success
# Records loaded: 0

# %% [markdown]
# Test DBT Operation

# %%
# Test dbt operation
print("🧪 Testing DBT Transformations")
print("=" * 50)

try:
    # Create a test context
    context = build_op_context()
    
    # Test the dbt operation
    result = run_dbt_transformations(context)
    
    print(f"✅ DBT operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Debug success: {result.get('debug_success', False)}")
    print(f"Run success: {result.get('run_success', False)}")
    print(f"Test success: {result.get('test_success', False)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ DBT test failed: {e}")
    print("This might be due to:")
    print("- Missing dbt configuration")
    print("- Database connection issues")
    print("- Missing dbt models")
# Out:
# 🧪 Testing DBT Transformations
# ==================================================
# 2025-07-16 03:38:05,156 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:05,158 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:05,241 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:05,257 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:05,258 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:05,329 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:05,336 - dagster.builtin - INFO - Starting dbt transformations
# 2025-07-16 03:38:05,337 - dagster.builtin - INFO - Running dbt debug...
# 2025-07-16 03:38:05,344 - dagster.builtin - ERROR - dbt debug failed: [WinError 2] The system cannot find the file specified
# ✅ DBT operation completed!
# Status: failed
# Debug success: False
# Run success: False
# Test success: False
# ❌ Error: dbt configuration error

# %% [markdown]
# Test YOLO Operation

# %%
# Test YOLO operation
print("🧪 Testing YOLO Enrichment")
print("=" * 50)

try:
    # Create a test context
    context = build_op_context()
    
    # Test the YOLO operation
    result = run_yolo_enrichment(context)
    
    print(f"✅ YOLO operation completed!")
    print(f"Status: {result.get('status', 'unknown')}")
    print(f"Images processed: {result.get('images_processed', 0)}")
    print(f"Detections found: {result.get('detections_found', 0)}")
    
    if result.get('status') == 'failed':
        print(f"❌ Error: {result.get('error', 'Unknown error')}")
    
except Exception as e:
    print(f"❌ YOLO test failed: {e}")
    print("This might be due to:")
    print("- Missing YOLO model files")
    print("- No images found for processing")
    print("- GPU/CUDA issues")
# Out:
# 🧪 Testing YOLO Enrichment
# ==================================================
# 2025-07-16 03:38:05,399 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:05,401 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:05,455 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:05,466 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:05,470 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:05,592 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:05,600 - dagster.builtin - INFO - Starting YOLO image enrichment
# 2025-07-16 03:38:05,625 - dagster.builtin - INFO - Processing 2535 images with YOLO
# Error loading YOLO model: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# 2025-07-16 03:38:05,778 - dagster.builtin - ERROR - Error in run_yolo_enrichment: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# ❌ YOLO test failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([ultralytics.nn.tasks.DetectionModel])` or the `torch.serialization.safe_globals([ultralytics.nn.tasks.DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# This might be due to:
# - Missing YOLO model files
# - No images found for processing
# - GPU/CUDA issues

# %% [markdown]
# ## Full Pipeline Execution
#
# Now let's run the complete pipeline and see how all operations work together.

# %%
# Execute the full pipeline
print("🚀 Executing Full Pipeline")
print("=" * 50)

try:
    # Execute the job
    result = execute_job(telegram_pipeline_job)
    
    if result.success:
        print("✅ Pipeline executed successfully!")
        print(f"Run ID: {result.run_id}")
        
        # Get execution summary
        for event in result.all_events:
            if event.event_type_value == "STEP_SUCCESS":
                print(f"✅ Step {event.step_key} completed successfully")
            elif event.event_type_value == "STEP_FAILURE":
                print(f"❌ Step {event.step_key} failed")
                print(f"   Error: {event}")
    
    else:
        print("❌ Pipeline execution failed!")
        for event in result.all_events:
            if event.event_type_value == "STEP_FAILURE":
                print(f"❌ Step {event.step_key} failed: {event}")
    
except Exception as e:
    print(f"❌ Pipeline execution error: {e}")
    print("Check your environment configuration and try again.")
# Out:
# 🚀 Executing Full Pipeline
# ==================================================
# ❌ Pipeline execution error: execute_job() missing 1 required positional argument: 'instance'
# Check your environment configuration and try again.

# %% [markdown]
# ## Pipeline Monitoring and Reporting
#
# Let's examine the pipeline results and generate reports.

# %%
# Analyze pipeline results
print("📊 Pipeline Results Analysis")
print("=" * 50)

try:
    # Get the latest run from Dagster instance
    instance = DagsterInstance.ephemeral()
    
    # List recent runs
    runs = instance.get_runs(limit=5)
    
    if runs:
        print(f"📈 Recent Pipeline Runs:")
        for run in runs:
            status = "✅ SUCCESS" if run.status.value == "SUCCESS" else "❌ FAILED"
            print(f"   {run.run_id[:8]}... - {status} - {run.start_time}")
        
        # Get the most recent run
        latest_run = runs[0]
        print(f"\n�� Latest Run Details:")
        print(f"   Run ID: {latest_run.run_id}")
        print(f"   Status: {latest_run.status.value}")
        print(f"   Start Time: {latest_run.start_time}")
        print(f"   End Time: {latest_run.end_time}")
        
        if latest_run.status.value == "SUCCESS":
            print("   ✅ Pipeline completed successfully!")
        else:
            print("   ❌ Pipeline failed - check logs for details")
    
    else:
        print("📭 No pipeline runs found")
        print("Run the pipeline first to see results")
        
except Exception as e:
    print(f"❌ Error analyzing results: {e}")
# Out:
# 📊 Pipeline Results Analysis
# ==================================================
# 2025-07-16 03:38:05,895 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:05,897 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:06,071 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 2025-07-16 03:38:06,099 - alembic.runtime.migration - INFO - Context impl SQLiteImpl.
# 2025-07-16 03:38:06,101 - alembic.runtime.migration - INFO - Will assume non-transactional DDL.
# 2025-07-16 03:38:06,297 - alembic.runtime.migration - INFO - Running stamp_revision  -> 46b412388816
# 📭 No pipeline runs found
# Run the pipeline first to see results

# %% [markdown]
# ## Configuration and Customization
#
# Learn how to customize the pipeline for your specific needs.

# %%
# Show pipeline configuration options
print("⚙️  Pipeline Configuration")
print("=" * 50)

# Get default configuration
from dags.telegram_pipeline import get_pipeline_config

config = get_pipeline_config()
print("📋 Default Configuration:")
for op_name, op_config in config.get('ops', {}).items():
    print(f"   {op_name}:")
    for key, value in op_config.get('config', {}).items():
        print(f"     {key}: {value}")

print("\n🔧 Customization Options:")
print("   1. Modify scrape_telegram_data config for different channels")
print("   2. Adjust load_raw_to_postgres batch sizes")
print("   3. Configure dbt project settings")
print("   4. Set YOLO confidence thresholds")
print("   5. Add custom schedules")

# Example: Custom configuration
print("\n💡 Example Custom Configuration:")
custom_config = {
    "ops": {
        "scrape_telegram_data": {
            "config": {
                "max_messages_per_channel": 500,  # Reduced from 1000
                "include_media": True
            }
        },
        "run_yolo_enrichment": {
            "config": {
                "confidence_threshold": 0.7,  # Increased from 0.5
                "model_path": "models/custom_yolo.pt"
            }
        }
    }
}
print("   Custom config created for testing")
# Out:
# ⚙️  Pipeline Configuration
# ==================================================
# 📋 Default Configuration:
#    scrape_telegram_data:
#      max_messages_per_channel: 1000
#      include_media: True
#    load_raw_to_postgres:
#      batch_size: 1000
#      retry_attempts: 3
#    run_dbt_transformations:
#      dbt_project_dir: dbt
#      profiles_dir: dbt
#    run_yolo_enrichment:
#      confidence_threshold: 0.5
#      model_path: models/yolo_medical.pt
#
# 🔧 Customization Options:
#    1. Modify scrape_telegram_data config for different channels
#    2. Adjust load_raw_to_postgres batch sizes
#    3. Configure dbt project settings
#    4. Set YOLO confidence thresholds
#    5. Add custom schedules
#
# 💡 Example Custom Configuration:
#    Custom config created for testing

# %% [markdown]
# ## Troubleshooting and Debugging
#
# Common issues and how to resolve them.

# %%
# Troubleshooting guide
print("🔧 Troubleshooting Guide")
print("=" * 50)

troubleshooting = {
    "Telegram Connection Issues": [
        "Check TELEGRAM_API_ID and TELEGRAM_API_HASH in .env",
        "Verify phone number format (+1234567890)",
        "Ensure internet connectivity",
        "Check for rate limiting"
    ],
    "Database Connection Issues": [
        "Verify DATABASE_URL format",
        "Check PostgreSQL is running",
        "Ensure database exists",
        "Check user permissions"
    ],
    "dbt Issues": [
        "Run 'dbt debug' to check configuration",
        "Verify dbt project structure",
        "Check profiles.yml setup",
        "Ensure dbt dependencies installed"
    ],
    "YOLO Issues": [
        "Check YOLO model files exist",
        "Verify CUDA/GPU setup",
        "Check image file paths",
        "Ensure ultralytics is installed"
    ],
    "Dagster Issues": [
        "Check dagster.yaml configuration",
        "Verify workspace setup",
        "Check Python environment",
        "Review Dagster logs"
    ]
}

for issue, solutions in troubleshooting.items():
    print(f"\n❓ {issue}:")
    for i, solution in enumerate(solutions, 1):
        print(f"   {i}. {solution}")

print("\n📞 For more help:")
print("   - Check Dagster documentation")
print("   - Review pipeline logs")
print("   - Test individual operations")
# Out:
# 🔧 Troubleshooting Guide
# ==================================================
#
# ❓ Telegram Connection Issues:
#    1. Check TELEGRAM_API_ID and TELEGRAM_API_HASH in .env
#    2. Verify phone number format (+1234567890)
#    3. Ensure internet connectivity
#    4. Check for rate limiting
#
# ❓ Database Connection Issues:
#    1. Verify DATABASE_URL format
#    2. Check PostgreSQL is running
#    3. Ensure database exists
#    4. Check user permissions
#
# ❓ dbt Issues:
#    1. Run 'dbt debug' to check configuration
#    2. Verify dbt project structure
#    3. Check profiles.yml setup
#    4. Ensure dbt dependencies installed
#
# ❓ YOLO Issues:
#    1. Check YOLO model files exist
#    2. Verify CUDA/GPU setup
#    3. Check image file paths
#    4. Ensure ultralytics is installed
#
# ❓ Dagster Issues:
#    1. Check dagster.yaml configuration
#    2. Verify workspace setup
#    3. Check Python environment
#    4. Review Dagster logs
#
# 📞 For more help:
#    - Check Dagster documentation
#    - Review pipeline logs
#    - Test individual operations

# %% [markdown]
# ## Next Steps
#
# Your Dagster pipeline is now ready for production use!

# %%
# Next steps and recommendations
print("�� Next Steps")
print("=" * 50)

next_steps = [
    "1. Set up production environment variables",
    "2. Configure database for production use",
    "3. Set up monitoring and alerting",
    "4. Create custom schedules for automation",
    "5. Add data quality checks",
    "6. Implement error handling and retries",
    "7. Set up logging and metrics collection",
    "8. Create backup and recovery procedures"
]

for step in next_steps:
    print(f"   {step}")

print("\n🚀 Ready to deploy!")
print("   Your Dagster pipeline is configured and ready for production use.")
print("   Use 'dagster dev' to start the UI and monitor your pipelines.")
# Out:
# �� Next Steps
# ==================================================
#    1. Set up production environment variables
#    2. Configure database for production use
#    3. Set up monitoring and alerting
#    4. Create custom schedules for automation
#    5. Add data quality checks
#    6. Implement error handling and retries
#    7. Set up logging and metrics collection
#    8. Create backup and recovery procedures
#
# 🚀 Ready to deploy!
#    Your Dagster pipeline is configured and ready for production use.
#    Use 'dagster dev' to start the UI and monitor your pipelines.
